# %%
# standard imports
import numpy as np
import pandas as pd
import networkx as nx

# for data exploration, cleaning, and visualization
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_csv('spotify_dataset.csv', on_bad_lines='skip', engine='python')

# %%
raw.head()
# Out:
#                             user_id                      "artistname"  \
# 0  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#
#                                          "trackname"  "playlistname"
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010

# %% [markdown]
# Renaming column names, doing some quick initial exploration of the data

# %%
# define a function to rename the columns
def rename_cols(df):
    columns = ['user_id', 'artist_name', 'track_name', 'playlist_name']
    df.columns = columns
    return df

data = rename_cols(raw)
data.head()
# Out:
#                             user_id                       artist_name  \
# 0  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#
#                                           track_name   playlist_name
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010

# %%
data.shape
# Out:
# (302639, 4)

# %%
data.describe()
# Out:
#                                  user_id  artist_name track_name playlist_name
# count                             302639       302229     302636        302639
# unique                               407        27792     154139          5192
# top     61baddf7207fea410abdc56e680fa869  Johnny Cash      Intro       Starred
# freq                               18835         1128        164         30622

# %%
data.artist_name.value_counts()
# Out:
# Johnny Cash                            1128
# Coldplay                               1127
# Red Hot Chili Peppers                  1117
# Daft Punk                              1097
# Arctic Monkeys                         1003
#                                        ...
# Gerardo Iacoucci                          1
# Jamin Winans                              1
# Michelle Pfeiffer                         1
# Magic Philharmonic Disney Orchestra       1
# The Finn Brothers                         1
# Name: artist_name, Length: 27792, dtype: int64

# %%
data.playlist_name.value_counts()
# Out:
# Starred                             30622
# Everything at once                   7877
# Spotify Library                      7640
# Strane                               6812
# Rich's iPhone                        4603
#                                     ...
# ¿Con quién se queda el perro?           1
# DMX — Where The Hood At                 1
# Mindy Smith                             1
# Dangerous (feat. Howard Jones) 2        1
# Never Say Never                         1
# Name: playlist_name, Length: 5192, dtype: int64

# %% [markdown]
# We want to connect two artists if they are placed in the same playlist.

# %%
# sort the playlists by playlist
data = data.sort_values(by=['playlist_name'])

playlists = {}
# create a dictionary of playlist : [*artists] key-value pairs
for artist, playlist in zip(data.artist_name, data.playlist_name):
    if playlist not in playlists:
        playlists[playlist] = [artist]
    else:
        # check if this artist is already in the list
        if artist not in playlists[playlist]:
            playlists[playlist].append(artist)

# %%
playlists
# Out:
# {' 3 point shot- jerry bergonzi': ['Jerry Bergonzi'],
#  ' Chopin Complete Edition': ['Frédéric Chopin'],
#  ' DMB - Live in Rio': ['Dave Matthews Band'],
#  ' Diamond Jubilee - A Classical Celebration': ['Della Jones',
#   'Bournemouth Symphony Orchestra',
#   'Waynflete Singers',
#   'Philip Jones Ensemble',
#   'Academy of St. Martin in the Fields',
#   'East of England Orchestra',
#   'The Royal Choral Society',
#   'BBC Concert Orchestra',
#   'Martin Loveday',
#   'Robert Ferriman',
#   'London Symphony Chorus'],
#  ' Hercules Original Soundtrack': ['Ricky Martin',
#   'Danny DeVito',
#   'Alan Menken',
#   'Jocelyn Brown',
#   'Lillias White',
#   'Roz Ryan',
#   'Boyzone',
#   'William Shakespeare',
#   'Roger Bart',
#   'Sounds Of Blackness',
#   'Belinda Carlisle',
#   'Charlton Heston'],
#  ' Punk-O-Rama': ['Sage Francis',
#   'I Against I',
#   'NOFX',
#   'Danger Doom',
#   'The Offspring',
#   'This Is Me Smiling',
#   'Millencolin',
#   'The Humpers',
#   'Guttermouth',
#   'Ten Foot Pole',
#   'Dropkick Murphys',
#   'Straight Faced',
#   'Horrorpops',
#   'The Special Goodness',
#   'Refused',
#   '98 Mute',
#   'Deviates',
#   'Descendents',
#   'Rancid',
#   'Bad Religion',
#   'Pennywise',
#   'The Bouncing Souls',
#   'Osker',
#   'Gas Huffer',
#   'Raised Fist',
#   'Beatsteaks',
#   'Pulley',
#   'Agnostic Front',
#   'Down By Law',
#   'H2O',
#   'Hot Water Music',
#   'Matchbook Romance',
#   'The Joykiller',
#   'Death By Stereo',
#   'The Distillers',
#   'Dwarves',
#   'Some Girls',
#   'Scatter The Ashes',
#   'No Fun At All',
#   'Madball',
#   'Union 13',
#   'Poison Idea',
#   'Tiger Army',
#   'T.S.O.L.',
#   'New Bomb Turks',
#   'Randy',
#   'Satanic Surfers',
#   'Bombshell Rocks',
#   'The (International) Noise Conspiracy',
#   '59 Times The Pain',
#   'All',
#   'Motion City Soundtrack',
#   'The Unseen',
#   'Vision',
#   'The Coup',
#   'Error',
#   'Tom Waits',
#   'Atmosphere',
#   'Division Of Laura Lee',
#   'Converge',
#   'Wayne Kramer',
#   'RKL',
#   'Voodoo Glow Skulls',
#   '1208',
#   'SNFU',
#   'The Weakerthans',
#   'Red Aunts',
#   'Downset',
#   'The Black Keys',
#   'Me First and the Gimme Gimmes',
#   'Roger Miret & The Disasters',
#   'U.S. Bombs',
#   'From First To Last',
#   'DFL',
#   'Transplants',
#   'Ikara Colt',
#   'The Matches',
#   'Total Chaos',
#   'Youth Group',
#   'The Cramps',
#   'Eyedea & Abilities',
#   'The Hives',
#   'Zeke',
#   'H20',
#   'Turbonegro',
#   'Nekromantix',
#   'Gentleman Jack Grisham',
#   'F-Minus',
#   'The Business'],
#  ' Sound Box Essentials Platinum Edition': ['Brent Dowe',
#   'Dennis Brown',
#   'Frankie Paul',
#   'Ken Boothe',
#   'Delroy Wilson',
#   'Johnny Clarke',
#   'John Holt',
#   'Barry Brown',
#   'Don Carlos',
#   'Cornell Campbell',
#   'Horace Andy',
#   'Dave Fluxy',
#   'Everton Blender',
#   'Marie Claire',
#   'Michael Rose',
#   'Robert Lee',
#   'Lukie D'],
#  ' Spring Awakening': ['Jonathan Groff',
#   'Lea Michele',
#   'Jonathan B. Wright',
#   'Lilli Cooper',
#   'John Gallagher, Jr.',
#   'Lauren Pritchard',
#   'Brian Johnson'],
#  ' The Best Of Jimi Hendrix': ['Jimi Hendrix'],
#  ' When I Was A Kid (up to about 13)': ['2Pac',
#   'Simple Plan',
#   'Bowling For Soup',
#   'Kid Rock',
#   'Eiffel 65',
#   'N Sync',
#   'Smash Mouth',
#   'Backstreet Boys',
#   'Gorillaz',
#   'JAY Z',
#   'Macy Gray',
#   'Collective Soul',
#   'blink-182',
#   'Green Day',
#   'Bush',
#   'Sugar Ray feat. Super Cat',
#   'Sum 41',
#   'Good Charlotte',
#   'Matchbox Twenty',
#   'Hootie & The Blowfish',
#   'Outkast',
#   'Bon Jovi',
#   'Hanson',
#   'Matt Nathanson',
#   '3 Doors Down',
#   'Everclear',
#   'Lit',
#   'The Goo Goo Dolls',
#   'Barenaked Ladies',
#   'Third Eye Blind',
#   'Britney Spears',
#   'The Offspring',
#   'Sublime',
#   'Santana',
#   'Fountains Of Wayne',
#   'The All-American Rejects',
#   'Eminem',
#   'Chumbawamba',
#   'U2'],
#  ' adam': ['Kyla La Grange',
#   'The All-American Rejects',
#   'Steve Hart',
#   'Donkeyboy',
#   'Alesso',
#   'Rebecca & Fiona',
#   'John De Sohn',
#   'Howie Day',
#   'Adrian Lux',
#   'Eric Turner',
#   'Matierro',
#   'Gnarls Barkley',
#   'Javier Colon',
#   'Milkman',
#   'Kill The Romance',
#   'Toots & The Maytals',
#   'Cyndi Lauper',
#   'Fergie',
#   'Broiler',
#   'Empire Of The Sun',
#   'The 1975',
#   'Sultan + Shepard ',
#   'De Vet Du',
#   'Mott The Hoople',
#   'Shaggy',
#   'S Club 7',
#   'Francesqa',
#   'John Mayer',
#   'Zac Brown Band',
#   'OneRepublic',
#   'Snow Patrol',
#   'Steve Miller Band',
#   'The Script',
#   'Avicii',
#   'Ylvis',
#   'Ray LaMontagne',
#   'Tungevaag',
#   'LP',
#   'Panda Da Panda',
#   'Walk the Moon',
#   'U2',
#   'The Hives',
#   'Macklemore & Ryan Lewis',
#   'Carly Rae Jepsen',
#   'Stender',
#   'deadmau5',
#   'Neehcs',
#   'Miike Snow',
#   'The Decemberists',
#   'Icona Pop',
#   'Mr. Big',
#   'Bob Marley & The Wailers',
#   'Autoerotique',
#   'Sebastian Ingrosso',
#   'Bad Company',
#   'Caramell',
#   'Cedric Gervais',
#   'Sweet Thing',
#   'Vanessa Carlton',
#   'Journey',
#   'BEK & Wallin',
#   'Michael Reinholdt',
#   'The Wanted',
#   'The Aggrolites',
#   'Mötley Crüe',
#   'Azure Blue',
#   'Flogging Molly',
#   'Medina',
#   'Commodores',
#   'Rupert Holmes',
#   'Bo Kaspers Orkester',
#   'Harry Nilsson',
#   'David Guetta',
#   'PSY',
#   'Lafayette',
#   'Cher Lloyd',
#   'Tom Petty',
#   'Klaas',
#   'Kina Grannis',
#   'Kenny Loggins',
#   'Deniz Koyu',
#   'SCNDL',
#   'Pacific Air',
#   'Kid Rock',
#   'Freddy Kalas',
#   'Manotett',
#   'Alex Goot',
#   'will.i.am',
#   'The Proclaimers',
#   'Rodriguez',
#   'Melody Club',
#   'Labrinth',
#   'American Authors',
#   'The Griswolds',
#   'Michael Jackson',
#   'Jorn',
#   'Movits!',
#   'Afrojack',
#   'Modest Mouse',
#   'Lorentz & Sakarias',
#   'Sheppard',
#   'Oasis',
#   'Boyce Avenue',
#   'Phillip Phillips',
#   'Owl City',
#   'Neil Young',
#   'Steve Aoki feat. Lovefoxxx',
#   'Martin Solveig',
#   'David Bowie',
#   'Michael Jackson Duet with Akon',
#   'Futures',
#   'Landis',
#   'Petra Marklund',
#   'Genesis',
#   'Wyclef Jean',
#   'Parry Gripp',
#   'Tom Waits',
#   'The Who',
#   'Paramore',
#   'Hapollo',
#   'Familjen',
#   'Jack Eye Jones',
#   'Jake Bugg',
#   'Swing Republic',
#   'Marvin Gaye',
#   'Passenger',
#   'Big Hits 2012',
#   'Matt Nathanson',
#   'Detektivbyrån',
#   'Kings Of Leon',
#   'Third Eye Blind',
#   'Urban Cone',
#   'Matoma',
#   'Redfoo',
#   'Henrik B',
#   'Nico & Vinz',
#   'Ivan Gough',
#   'Matisyahu',
#   'Nicky Romero',
#   'The Doobie Brothers',
#   'The Tallest Man On Earth',
#   'Take That',
#   'Mose Allison',
#   'Boemklatsch',
#   'Klingande',
#   'Coll',
#   'Asaf Avidan',
#   'Trafassi & DJ Maurice',
#   'The Naked And Famous',
#   'Counting Crows',
#   'Bob Sinclar',
#   'Joe Walsh',
#   'Black Grape',
#   'Anders Nilsen',
#   'Capital Cities',
#   'Jason Risk',
#   'Mike Farris',
#   'William Ekh',
#   'Dead by April',
#   'Austin Mahone',
#   'Westbound Train',
#   'Steve Aoki',
#   'Taylor Swift',
#   'Bowling For Soup',
#   'Axwell^Ingrosso',
#   'Eagle-Eye Cherry',
#   'Fun.',
#   'Blåbær',
#   'Lynyrd Skynyrd',
#   'Tiësto',
#   'Swedish House Mafia',
#   "The Mowgli's",
#   'Gym Class Heroes',
#   'Roman Lob',
#   'The Rolling Stones',
#   'Jimmy Cliff',
#   'Sam Cooke',
#   'Martin Tungevaag',
#   'Jackson 5',
#   'Will Sparks',
#   'Nickelback',
#   'Music Super Circus',
#   'Spin Doctors',
#   'Ziggy Marley',
#   'P!nk',
#   'New World Sound',
#   '3LOGY',
#   'Bloodhound Gang',
#   'Good Charlotte',
#   'Ed Sheeran',
#   'Tracy Chapman',
#   'Jesper Nohrstedt',
#   'Eagles',
#   'Retinue',
#   "Guns N' Roses",
#   'Peter Bjorn And John',
#   'Deaf Havana',
#   'The Black Eyed Peas',
#   'Air Traffic Controller',
#   'The Temper Trap',
#   'Rascal Flatts',
#   'Anders Rudseter',
#   'Swingfly',
#   'Suzanne Vega',
#   'Bruno Mars',
#   'Far East Movement',
#   'Chester See, Kevjumba & Ryan Higa',
#   'Kelly Clarkson',
#   'Georgie Fame',
#   'Johan Agebjörn',
#   'Otto Knows',
#   'The Dingoes',
#   'G.R.L.',
#   'Aerosmith',
#   'The Buggles',
#   'Dimitri Vegas & Like Mike',
#   'Stiftelsen',
#   'Den svenska björnstammen',
#   'Destineak',
#   'Givers'],
#  ' yeah pin xx': ['The xx', 'Pinback', 'Yeah Yeah Yeahs', 'Caribou'],
#  '#N': [nan,
#   'Zedd ft Foxes',
#   'Goldroom feat. Chela',
#   'The xx',
#   'Liar',
#   'Lana Del Rey',
#   'India Martinez'],
#  '#Sundays': ['Madeon', 'Coldplay', 'Don Diablo', 'The Script'],
#  '#tbt': ['Lady Gaga',
#   'Jonas Brothers',
#   'Queens Of The Stone Age',
#   'Fall Out Boy',
#   '3OH!3',
#   'Red Hot Chili Peppers',
#   'Katy Perry'],
#  '#weATLast Wedding Soundtrack': ['Frank Sinatra',
#   'Sam Cooke',
#   'The Beatles',
#   'Etta James',
#   'Frankie Valli & The Four Seasons',
#   'Harry Nilsson',
#   'Elliott Smith',
#   'Ra Ra Riot',
#   'The Middle East',
#   'Billie Holiday',
#   'Simon & Garfunkel',
#   'Edward Sharpe & The Magnetic Zeros',
#   'Air',
#   'Melody Gardot',
#   'Cat Power',
#   'Nick Drake',
#   'The Walkmen',
#   'The Magnetic Fields',
#   'The Association',
#   'Regina Spektor'],
#  '(RETRO)Hardcore vibes for you': ['Dune',
#   'Future Breeze',
#   'U96',
#   'Paul van Dyk',
#   'Dance 2 Trance',
#   'DJ Jean',
#   'Technohead',
#   'Klubbheads'],
#  '(not so) new shhyt': ['The Neighbourhood',
#   'Maximo Park',
#   'Walk Off the Earth',
#   'Jenny Lewis',
#   'Kyle Andrews',
#   'Kurt Vile',
#   'Bastille',
#   'Cass McCombs',
#   'Haim',
#   'Two Door Cinema Club',
#   'The Decemberists',
#   'King',
#   'Regina Spektor',
#   'Donora',
#   'Phoenix'],
#  '**songs for summer**': ['Coasts',
#   'The 1975',
#   'The Neighbourhood',
#   'Dale Earnhardt Jr. Jr.',
#   'Vance Joy',
#   'Savoir Adore',
#   'Satellite Stories',
#   'Rogue Wave',
#   'Fou De Toi',
#   'Andrew Bird',
#   'Small Black',
#   'Grouplove',
#   'Blondfire'],
#  '*Rock Boat XV': ['Scars On 45',
#   'Paul Pfau',
#   'Von Grey',
#   'The Roosevelts',
#   'Steve Everett',
#   'Brian Collins',
#   'Carbon Leaf',
#   'Brian Collins Band',
#   'Radio Birds',
#   'Gareth Asher',
#   'Will Hoge',
#   'Broken Anchor',
#   'The Shadowboxers',
#   'Simplified',
#   'Honor By August',
#   'Kris Allen',
#   'Melodime',
#   'Sister Hazel',
#   'Andy Suzuki & The Method',
#   'Amy Gerhartz',
#   'Stokeswood',
#   'Michael Franti & Spearhead',
#   'Red Wanting Blue',
#   'Vintage Blue',
#   'The Alternate Routes',
#   'Hey Monea!',
#   'Barenaked Ladies',
#   "The Mowgli's"],
#  '...': ['Stone Temple Pilots',
#   'Wolfmother',
#   'Lenny Kravitz',
#   'Gary Clark Jr.',
#   'The Strokes',
#   'Florence + The Machine',
#   'Alabama Shakes',
#   'Yeah Yeah Yeahs',
#   'My Chemical Romance',
#   'The Darkness',
#   'Jet',
#   'Edward Sharpe & The Magnetic Zeros',
#   'Joe Satriani',
#   'Juanes',
#   'Grace Potter & The Nocturnals',
#   'The Black Keys',
#   'The Smashing Pumpkins',
#   'Foo Fighters',
#   'Rye Coalition',
#   'Les Savy Fav'],
#  '//***LOLLA***//': ['Major Lazer',
#   'alt-J',
#   'Tame Impala',
#   'Django Django',
#   'Coasts',
#   'Marina and The Diamonds',
#   'The Weeknd',
#   'Glass Animals',
#   'Brand New',
#   'Angus & Julia Stone',
#   'A$AP Rocky',
#   'Kid Cudi',
#   'The Wombats',
#   'FKA twigs',
#   'Calvin Harris',
#   'Dillon Francis',
#   'TV On The Radio',
#   'Tyler, The Creator',
#   'Hot Chip',
#   'Cold War Kids',
#   'Chet Faker',
#   'Angus',
#   'Toro Y Moi',
#   'OneRepublic',
#   'Ariana Grande',
#   'Alesso',
#   'Kygo',
#   'Kyla La Grange',
#   'Flume'],
#  '00-Playlist': ['Jay-Z and Kanye West'],
#  "00s 2000s 2000's": ['Amy Macdonald',
#   'Coldplay',
#   'Dungen',
#   'Radiohead',
#   'Keane',
#   'Blonde Redhead',
#   'Snow Patrol',
#   'PJ Harvey',
#   'Nikkfurie',
#   'Mercury Rev',
#   'The Dresden Dolls',
#   'Paul McCartney',
#   'Echo And The Bunnymen',
#   'Hard-FI',
#   'DeVotchKa',
#   'The Kooks',
#   'Ian Brown',
#   'MGMT',
#   'Off The Record Karaoke',
#   'Flor-de-Lis',
#   'Augie March',
#   'Bee Gees',
#   'Helloween',
#   'R.E.M.',
#   'Doves',
#   'Ashram',
#   'Morrissey',
#   'Emiliana Torrini',
#   'Umay Umay',
#   'Mahala Rai Banda',
#   'The White Stripes',
#   'Kings Of Convenience',
#   'Santigold',
#   'Kasabian',
#   'Weezer',
#   'The Raconteurs',
#   "Tapes 'n Tapes",
#   'Moby',
#   'The Fratellis',
#   'Dizzee Rascal',
#   'Spoon',
#   'Ocean Colour Scene',
#   'Ladytron',
#   'Belle & Sebastian',
#   'Phoenix',
#   'Maroon 5',
#   'Vitamin String Quartet',
#   'The Long Blondes',
#   'Tindersticks',
#   'Mirah',
#   'Korn',
#   'The Killers',
#   'My Chemical Romance',
#   'Bloc Party',
#   'Johnny Cash',
#   'Louise Attaque',
#   'Rihanna',
#   'Creed',
#   'Q-Tip',
#   'Roots Manuva',
#   'a-ha',
#   'U2',
#   'Redd',
#   'Patrick Cassidy',
#   'Estrella Morente',
#   'Tegan And Sara',
#   'Starsailor',
#   'The Decemberists',
#   'Alanis Morissette',
#   'Architecture In Helsinki',
#   'The Strokes',
#   'Michael Jackson',
#   'The Mummers',
#   'The Sleepy Jackson',
#   'The Gathering',
#   'The Last Shadow Puppets',
#   'Christian Basso',
#   'A Perfect Circle',
#   'Zero 7',
#   'Tori Amos Featuring Damien Rice',
#   'Portishead',
#   'Clinic',
#   'Voxtrot',
#   'St. Vincent',
#   'The Maccabees',
#   'Porcupine Tree',
#   'The Libertines',
#   'The Clientele',
#   'The Avalanches',
#   'The Offspring',
#   'Fleet Foxes',
#   'The Pipettes',
#   'Manu Chao',
#   'Bruno Coulais',
#   'Fischerspooner',
#   'Arcade Fire',
#   'Delays',
#   'Deerhunter',
#   'The Thermals',
#   'Manic Street Preachers',
#   'Chumbawamba',
#   'Yann Tiersen',
#   'Blur',
#   'Enya',
#   'The Tellers',
#   'Björk',
#   'South',
#   'M.I.A.',
#   'Iron Maiden',
#   'Chris Isaak',
#   'Hot Chip',
#   'Cake',
#   'Esbjörn Svensson Trio',
#   'Travis',
#   'The Divine Comedy',
#   'Clyde Federal',
#   'Jens Lekman',
#   'Elliott Smith',
#   'The Cranberries',
#   'Dionysos',
#   'Oi Va Voi',
#   'Beirut',
#   'JAY Z',
#   'System Of A Down',
#   'Amadou & Mariam',
#   'Deportivo',
#   'The Pierces',
#   'Jeanne Cherhal',
#   'Beck',
#   'Supergrass',
#   'Lamb',
#   'The Chemical Brothers',
#   'Autechre',
#   'Talib Kweli',
#   'Missy Elliott',
#   'James',
#   'The Shins',
#   'Razorlight',
#   'CocoRosie',
#   'MIKA',
#   'The Go! Team',
#   'Mogwai',
#   'The Thrills',
#   'Lily Allen',
#   'Kanye West',
#   'Teenage Fanclub',
#   'Caesars',
#   'Animal Collective',
#   'Therion',
#   'Poney Express',
#   'Bright Eyes',
#   'Oasis',
#   'Mendetz',
#   'Noir Désir',
#   'Juanes',
#   'Sonny J',
#   'Röyksopp',
#   'Cut Copy',
#   'No Doubt',
#   "Margot & The Nuclear So And So's",
#   'The Fiery Furnaces',
#   'Obadiah Parker',
#   'Regina Spektor',
#   'The Good, The Bad and The Queen',
#   'Hip Hop Rappers & DJs',
#   'Antony & The Johnsons',
#   'The Futureheads',
#   'Devotchka',
#   'The Fray',
#   'Madonna',
#   'I Love You! Project',
#   'Peter Bjorn And John',
#   'Sufjan Stevens',
#   'Estelle',
#   'Air',
#   'Yeah Yeah Yeahs',
#   'Adele',
#   'Fugazi',
#   'Vampire Weekend',
#   'Shaggy',
#   'The Cure',
#   'Tinariwen',
#   'Pink Martini',
#   'Anathema',
#   'Pato Fu',
#   'Interpol',
#   'Franz Ferdinand',
#   'Burial',
#   'The Vegastones',
#   'Red Hot Chili Peppers',
#   'Ash',
#   'Calogero',
#   'Benjamin Biolay',
#   'Electric Six',
#   'Depeche Mode',
#   'Glasvegas',
#   'Bumcello',
#   'The Pages',
#   'Faithless',
#   'Gnarls Barkley',
#   'Songs: Ohia',
#   'The Cardigans',
#   'The Zutons',
#   'Parov Stelar',
#   'The Rumble Strips',
#   'Opeth',
#   'Camera Obscura',
#   'The Coral',
#   'Kaiser Chiefs',
#   'Jem',
#   'Godspeed You! Black Emperor',
#   'Brainstorm',
#   'Linkin Park',
#   'Tori Amos',
#   'The Presets',
#   'Crystal Castles',
#   'Robbie Williams',
#   'Bitter:Sweet',
#   'The Dears',
#   'The Hives',
#   'The Flaming Lips',
#   'Kate Nash',
#   'Sia',
#   'Rosalia De Souza',
#   'My Morning Jacket',
#   'Arctic Monkeys',
#   'Pelle Carlberg',
#   'Modest Mouse',
#   'Mägo de Oz',
#   'Sigur Rós',
#   'Gorillaz',
#   'The Gentle Waves',
#   'David Byrne',
#   'Helldorado',
#   'Silver Mt Zion',
#   'Guided By Voices',
#   'David Fonseca',
#   'Sunrise Avenue',
#   'Babybird',
#   'The Beta Band',
#   'Grandaddy',
#   'LCD Soundsystem',
#   "K's Choice",
#   'Citizen Cope',
#   'Death Cab for Cutie',
#   'Passion Pit',
#   'Metallica',
#   'Gravenhurst',
#   'Pedram',
#   'Mando Diao',
#   'Junior Senior',
#   'Panjabi MC',
#   'Feist',
#   'Muse',
#   'Wir Sind Helden',
#   'The Organ',
#   'The Postal Service',
#   'Norah Jones',
#   'Mos Def',
#   'Joan As Police Woman',
#   'She Wants Revenge',
#   'Amy Winehouse',
#   'Daft Punk',
#   'DJ Shadow',
#   'Workout Heroes',
#   'Marcy Playground',
#   'Vienna Teng',
#   'Richard Hawley',
#   'Panda Bear',
#   'Kite In The Air',
#   'Tunng',
#   'Jazzamor',
#   'British Sea Power',
#   'Aereogramme',
#   'Stephen Malkmus',
#   'OutKast',
#   'Milow',
#   'Apocalyptica',
#   'I Monster',
#   'Frida Hyvönen',
#   'Oasis For Piano',
#   "Sinead O'Connor",
#   'Rilo Kiley',
#   "LE PEUPLE DE L'HERBE|JC 001",
#   'Kings Of Leon',
#   'Jet',
#   "Fun Lovin' Criminals",
#   'The Dandy Warhols',
#   'Cinerama',
#   'Rufus Wainwright',
#   'Eminem',
#   'Akon'],
#  '01010': ['Mikael Gabriel', 'Konna', 'Petri Nygård'],
#  '0611 dance your monday blues away at your office desk mixtape': ['Joya Landis',
#   'The Paragons',
#   'UB40',
#   'Joe Jackson',
#   'Twins Seven',
#   'Franck Biyong and the Afrolectric Orkestra feat MELISSA JAMES',
#   'Debruit',
#   'Bill Withers',
#   'Bassfort',
#   'Matthew Dear',
#   'Nic Sarno',
#   'The Tartans',
#   'Shinehead',
#   'Byron Lee'],
#  '0612 the day was made with that exchanged smile w/ the perfect stranger on the morning train ride mixtape': ['Nat King Cole',
#   'Jorgen Ingmann',
#   'Simon Baker',
#   'Mr Twin Sister',
#   'Joséphine Baker',
#   'The Postal Service',
#   'Al Bowlly',
#   "The O'Jays",
#   'Eydie Gorme',
#   'Kings Of Convenience',
#   'Matthew Herbert',
#   'Fur',
#   'Eddie Roberts',
#   'Astrud Gilberto',
#   'Erykah Badu',
#   'Arthur Russell'],
#  '1 augustus rest': ['Eddie Floyd',
#   'India.Arie',
#   'Jackson 5',
#   'Raphael Saadiq',
#   'Curtis Mayfield',
#   'Jamie Lidell',
#   'John Barry Orchestra',
#   'Luther Vandross',
#   'FaltyDL',
#   'The Pasadenas',
#   'Phoenix',
#   'Simply Red',
#   'The Temptations',
#   'Bonobo',
#   'Klangkarussell',
#   'The Jacksons',
#   'Staygold',
#   'Mayer Hawthorne',
#   'The Whitest Boy Alive',
#   'Funkommunity',
#   'Beyoncé',
#   'Stevie Wonder',
#   'Pharrell Williams',
#   'Incognito',
#   'Jazzanova',
#   'Negrocan'],
#  '1 untitled playlist': ['The Five Stairsteps',
#   'Marvin Gaye',
#   'Johnnie Taylor',
#   'Harold Melvin & The Blue Notes',
#   'Freda Payne',
#   'The Chi-Lites',
#   'Brenton Wood',
#   'Bill Withers',
#   'Cornelius Brothers & Sister Rose',
#   'Gil Scott-Heron',
#   'The Supremes',
#   'Sly & The Family Stone',
#   'The Staple Singers',
#   'The Delfonics',
#   'Joe Cuba',
#   'Charles Wright & The Watts 103rd Street Rhythm Band',
#   'Curtis Mayfield',
#   'The Commodores',
#   'The Stylistics',
#   'Ray Charles'],
#  '10 Ft. Ganja Plant': ['10 Ft. Ganja Plant'],
#  '10 mejores discos argentinos': ['Vox Dei',
#   'Pescado Rabioso',
#   'Charly García',
#   'Andrés Calamaro',
#   'Sumo',
#   'Los Fabulosos Cadillacs',
#   'Los Abuelos De La Nada',
#   'Soda Stereo'],
#  '100 Greates Rock Guitar Solo': ['Micheal Jackson',
#   'Pantera',
#   'Pink Floyd',
#   'Lynyrd Skynyrd',
#   'Steve Vai',
#   'Living Colour',
#   'Jethro Tull',
#   'Metallica',
#   'Santana',
#   'Eric Clapton',
#   'Frank Zappa',
#   'Cream',
#   'Ozzy Osbourne',
#   'Neil Young',
#   'Deep Purple',
#   'The Smashing Pumpkins',
#   'Van Halen',
#   'Soundgarden',
#   'Rolling Stones',
#   'Eagles',
#   'Alice In Chains',
#   'Jeff Beck',
#   'Acdc',
#   'Rage Against The Machine',
#   'Eric Johnson',
#   'Led Zeppelin',
#   'The Beatles',
#   'Jimi Hendrix',
#   'Pearl Jam',
#   'King Crimson',
#   'Funkadelic',
#   'Nirvana',
#   'Chuck Berry',
#   'Steely Dan',
#   'Derek And The Dominos',
#   'The Doors',
#   'Prince',
#   'The Allman Brothers Band',
#   'Queen',
#   'Yes',
#   'Rush',
#   'Stevie Ray Vaughan',
#   'The Who',
#   'Black Sabbath',
#   'Aerosmith',
#   'David Bowie',
#   'Ozzy Osborne',
#   "Guns 'n' Roses",
#   'Radiohead',
#   'Dream Theater',
#   'Sublime',
#   'Kiss',
#   'Joe Satriani',
#   'The Kinks',
#   'Zz Top',
#   'Phish',
#   'Ted Nugent',
#   'Dire Straits',
#   'Yngwie Malmsteen',
#   'Velvet Underground',
#   'Bb King',
#   'Janes Addiction',
#   'Stray Cats',
#   'Grateful Dead'],
#  '100 best guitar classics': ['Alfonso Moreno/Deborah Mariotti/London Symphony Orchestra/Enrique Bátiz',
#   'Anthony Bailes',
#   'Sharon Isbin',
#   'Julian Bream/Sir Simon Rattle',
#   'Angel Romero/London Symphony Orchestra/André Previn',
#   'Christopher Parkening/Academy of St Martin-in-the-Fields/Iona Brown',
#   'Eliot Fisk',
#   'Wulfin Lieske',
#   'Oscar Ghiglia',
#   'Manuel Barrueco',
#   'Julian Byzantine',
#   'Manuel Barrueco/London Symphony Orchestra/Jeremy Lubbock',
#   'Christopher Parkening',
#   'Ernesto Bitetti/Philharmonia Orchestra/Antoni Ros Marbá',
#   'Ernesto Bitetti',
#   'Carlos Bonell',
#   'Andres Segovia',
#   'Pierre Laniau',
#   'Christopher Parkening/Los Angeles Chamber Orchestra/Paul Shure',
#   'Alfonso Moreno/Minerva Garibay/Cecilia López/Jesús Ruiz/Orquesta Sinfonica del Estado de México/Enrique Bátiz',
#   'Dario Rossetti-Bonell',
#   'Angel Romero',
#   'Manuel Barrueco/David Tanenbaum',
#   'Christopher Parkening/Los Angeles Chamber Orchestra/Ronald Ravenscroft',
#   'André Previn'],
#  '10c/u': ['LCD Soundsystem',
#   'Arcade Fire',
#   'The National',
#   'Gorillaz',
#   'Babasonicos',
#   'The xx',
#   'Devendra Banhart',
#   'The Flaming Lips'],
#  '10cc - 10cc': ['10cc'],
#  '10cc - Sheet Music': ['10cc'],
#  '10cc - Tenology': ['10cc'],
#  '111km': ['Glass Animals',
#   'Purity Ring',
#   'Stereo Express',
#   'Florence + The Machine',
#   'Wiz Khalifa',
#   'Little Green Cars',
#   'The xx',
#   'Tei Shi',
#   'Sam Smith',
#   'Lapsley',
#   'Snoop Lion',
#   'Ninsun Poli',
#   'Rihanna',
#   'James Blake',
#   'Wild Belle',
#   'Kanye West',
#   'Astrid S',
#   'Delilah',
#   'How To Dress Well',
#   'Tove Styrke',
#   'Ben Howard',
#   'Wet',
#   'Lost Frequencies',
#   'Lana Del Rey'],
#  '120327': ['Amaranthe',
#   'Deathember',
#   'Nero',
#   'Raised Fist',
#   'Sabaton',
#   'The Unguided',
#   'In Flames',
#   'BABYMETAL',
#   'Pendulum'],
#  '120607': ['In Flames',
#   'Five Finger Death Punch',
#   'Engel',
#   'Avenged Sevenfold',
#   'Billy Talent',
#   'Volbeat',
#   'Papa Roach',
#   'Stone Sour',
#   'Backyard Babies',
#   'DragonForce'],
#  '18 Months': ['Calvin Harris'],
#  '180': ['OutKast',
#   'A Tribe Called Quest',
#   '50 Cent',
#   'The Damned',
#   'Coolio',
#   'JAY Z',
#   'Nas',
#   '2Pac',
#   'Foo Fighters',
#   'Eminem',
#   'Tom Petty'],
#  '1901': ['Passenger',
#   'Sam Smith',
#   'Robbie Williams',
#   'Everything But The Girl',
#   'Jake Bugg',
#   'St. Vincent',
#   'Hem',
#   'Birdy',
#   'Bon Iver & St. Vincent',
#   'Paloma Faith',
#   "Sinead O'Connor",
#   'The Kooks',
#   'Maps & Atlases',
#   "Anita O'Day"],
#  "1950's": ['Bill Haley',
#   'The Spaniels',
#   'The Beach Boys',
#   'Frankie Lymon & The Teenagers',
#   'The Everly Brothers',
#   'Chris Montez',
#   'The Champs',
#   'Dion & The Belmonts',
#   'Eddie Cochran',
#   'The Silhouettes',
#   'Chuck Berry',
#   'Little Anthony & The Imperials',
#   'The Ronettes',
#   'Ritchie Valens',
#   'Dion',
#   'Eric Carmen',
#   'The Five Satins',
#   'The Chordettes',
#   'John Travolta',
#   'Jerry Lee Lewis',
#   'Johnny Kidd & The Pirates',
#   'Elvis Presley',
#   'The Diamonds',
#   'Mickey & Sylvia',
#   'Neil Sedaka',
#   'Buddy Holly',
#   'Thurston Harris'],
#  '1980-1990': ['Simple Minds',
#   'Ultravox',
#   'Alphaville',
#   'John Cafferty',
#   'Shannon',
#   'Duran Duran',
#   'Pet Shop Boys',
#   'Billy Ocean',
#   'Wang Chung',
#   'Lionel Richie',
#   'Aneka',
#   'The Power Station',
#   'Robert Tepper',
#   'Go West',
#   'Cyndi Lauper',
#   'Baltimora',
#   'Phil Collins',
#   'Erasure',
#   'Don Johnson',
#   'Talk Talk',
#   'Cheap Trick',
#   'Roachford',
#   'Tears For Fears',
#   'Eurythmics',
#   'The Human League',
#   'Steve Winwood',
#   'Orchestral Manoeuvres In The Dark',
#   'Thompson Twins',
#   'Genesis',
#   'Thomas Dolby',
#   'Jan Hammer',
#   'Naked Eyes',
#   'Heart',
#   'Dusty Springfield',
#   'New Order',
#   'Matthew Wilder',
#   'Mr. Mister',
#   'Robbie Nevil',
#   'Blondie',
#   'George Michael',
#   'Huey Lewis & The News',
#   'Corey Hart',
#   'Depeche Mode',
#   'Roxy Music',
#   'Pat Benatar',
#   'Prince',
#   'Men At Work',
#   'Howard Jones',
#   'Rod Stewart',
#   'Culture Club',
#   'Living In A Box',
#   'Scandal',
#   'New Kids On The Block',
#   'Foreigner',
#   'a-ha',
#   'Frankie Goes To Hollywood',
#   'Rick Astley',
#   'A Flock Of Seagulls',
#   'ABC',
#   'Dire Straits',
#   'Kajagoogoo',
#   'INXS',
#   'When In Rome',
#   'Animotion',
#   'The Fixx',
#   'Laura Branigan',
#   'Johnny Hates Jazz',
#   'Bucks Fizz',
#   'Sandra'],
#  '1984 for you': ['Years & Years',
#   'Chris Montez',
#   'Frànçois & The Atlas Mountains',
#   'Marmalade',
#   'The Maccabees',
#   'Foals',
#   'Caribou',
#   'Hot Chip',
#   'Death In Vegas',
#   'Vondelpark',
#   'Pictureplane',
#   'Prince',
#   'Spoon',
#   'LCD Soundsystem',
#   'Drake',
#   'David Bowie',
#   'Elite Gymnastics',
#   'Deacon Blue',
#   'Orchestral Manoeuvres In The Dark',
#   'Emmy The Great',
#   'SNAP!',
#   'Stereolab',
#   'Beirut',
#   'The Naked And Famous',
#   'We Are Scientists',
#   'Yelle',
#   'Rodriguez',
#   'Twin Shadow',
#   'Rupert Holmes',
#   'The Cranberries',
#   'Neon Neon',
#   'The Human League',
#   'Public Enemy',
#   'Bruce Springsteen',
#   'Gnarls Barkley',
#   'Squeeze',
#   'Real McCoy',
#   'The Antlers',
#   'The Cure',
#   'Architecture In Helsinki',
#   'Chromatics',
#   'Grimes',
#   'Major Lazer',
#   'Fine Young Cannibals',
#   'The Weeknd',
#   'Interpol',
#   'He Is We',
#   'Craft Spells',
#   'Freezepop',
#   'The Flaming Lips',
#   'Erasure',
#   'Electrelane',
#   'Roy Orbison',
#   'New Order',
#   'Midnight Oil',
#   'The Ronettes',
#   'NZCA LINES',
#   'Wintersleep',
#   'The Shins',
#   'Broken Social Scene',
#   'Ben Khan',
#   'Thieves Like Us',
#   'Arcade Fire',
#   'Spandau Ballet',
#   'Yo La Tengo',
#   'Mystery Jets',
#   'Toto',
#   'Tilly And The Wall',
#   'Stars',
#   'The Very Best',
#   'Ultravox',
#   'Braids',
#   'The xx',
#   'Bloc Party',
#   'Porcelain Raft',
#   'Belle & Sebastian',
#   'Warpaint',
#   'Grizzly Bear',
#   "Bot'Ox",
#   'Paul Simon',
#   'Minotaur Shock',
#   'James',
#   'Massive Attack',
#   'The Tallest Man On Earth',
#   'Furniture',
#   'Haddaway',
#   'Pixies'],
#  '1nce Again - Radio Version': ['The Pharcyde',
#   'Smif-N-Wessun',
#   'A Tribe Called Quest',
#   'Pete Rock & C.L. Smooth',
#   'Souls Of Mischief'],
#  '2 Chainz - Based On A T.R.U. Story': ['2 Chainz'],
#  '2 Chainz – B.O.A.T.S. II #METIME': ['2 Chainz'],
#  '2 Chainz — B.O.A.T.S. II #METIME': ['2 Chainz'],
#  '2 am Rooftop Music': ['Flying Lotus',
#   'Devin The Dude',
#   'Kanye West',
#   'Method Man',
#   'Reflection Eternal',
#   'Mary J. Blige',
#   'Erykah Badu',
#   'Mac Miller',
#   'Wiz Khalifa',
#   'Kash',
#   'Mos Def',
#   'Frank Ocean',
#   'Redman',
#   '9th Wonder',
#   'Big Sean',
#   'Rick Ross',
#   'Kendrick Lamar',
#   'Tyler, The Creator',
#   'Big K.R.I.T.'],
#  '2 untitled playlist ': ['The Clash',
#   'Ween',
#   'The Flaming Lips',
#   'Chicago',
#   'Jim Croce',
#   'Daft Punk',
#   'Sly & The Family Stone',
#   'No Doubt',
#   'John Denver',
#   'Nirvana',
#   'Leonard Cohen',
#   'The Commodores',
#   'David Bowie',
#   'Benny Mardones',
#   'Lou Reed',
#   'Asswipe S. Perry',
#   'Massive Attack',
#   'Harry Nilsson',
#   'Blue Oyster Cult',
#   'Tricky',
#   'Radiohead',
#   'Gil Scott-Heron',
#   'Roberta Flack',
#   'The Beach Boys',
#   'Morcheeba',
#   'Carly Simon',
#   'The Manhattans',
#   'Beck'],
#  '2000trees Mixtape': ['Itch',
#   'Slaves',
#   'Maybeshewill',
#   'The St Pierre Snake Invasion',
#   'Arcane Roots',
#   'Kids In Glass Houses',
#   'Dan Le Sac vs Scroobius Pip',
#   'Get Cape. Wear Cape. Fly',
#   'Jamie Lenman',
#   'Little Matador',
#   'Public Service Broadcasting',
#   'Hawk Eyes',
#   'Nordic Giants',
#   'Versechorusverse',
#   'Darlia',
#   'Band Of Skulls'],
#  '2010': ['Skream ft. Sam Frank',
#   'Best Coast',
#   'Dirty Projectors',
#   'Wild Beasts',
#   'Blakroc',
#   'Local Natives',
#   'Jamie Woon',
#   'Beach House',
#   'The National',
#   'Skream',
#   'Darkstar',
#   'Wild Nothing',
#   'Laura Marling',
#   'The Tallest Man On Earth',
#   'Sleigh Bells',
#   'Starkey',
#   'Four Tet',
#   'The Drums',
#   'Yeasayer',
#   'James Blake',
#   'Girls',
#   'Delphic',
#   'The Pains Of Being Pure At Heart',
#   'Devlin',
#   'Deerhunter',
#   'Skream ft. Dbridge & instra:mental',
#   'Mj Cole',
#   'Dogzilla',
#   'Daft Punk',
#   'Skream ft. Freckles',
#   'Skream ft. La Roux',
#   'Skream ft. Murs'],
#  '2010 - 2014': ['The Rapture',
#   'La Casa Azul',
#   'Heroes Del Silencio',
#   'Dorian',
#   'Eminem',
#   'RENZO RUBINO',
#   'Of Monsters and Men',
#   'Take That',
#   'Stay',
#   'MIKA',
#   'Lori Meyers',
#   'Franz Ferdinand',
#   'Quique Gonzalez',
#   'Huecco',
#   'M-Clan',
#   'Izal',
#   'Incubus',
#   'Poncho K',
#   'Ivan Ferreiro',
#   'Manos De Topo',
#   'Papa Topo',
#   'Angel Stanich',
#   'Catpeople',
#   'Raphael',
#   'Mürfila',
#   "Dead Man's Bones",
#   'Swedish House Mafia',
#   'One Night Only',
#   'Varry Brava',
#   'Capital Cities',
#   'Giuradei',
#   'Colapesce',
#   'Carlos Sadness',
#   'The Lonely Island',
#   'The New Pornographers',
#   'The Kooks',
#   'Sidecars',
#   'Justin Timberlake',
#   'Foals',
#   'The Sunday Drivers',
#   'Sr. Chinarro',
#   'Sugarless',
#   'Second',
#   'My Chemical Romance',
#   'Zoé',
#   'Lily Allen',
#   'Arcade Fire',
#   'Mando Diao',
#   'The Shins',
#   'Russian Red',
#   'Kavinsky',
#   'Pereza',
#   'Maika Makovski',
#   'The Drums',
#   'Kings Of Leon',
#   'Leiva (Pereza)',
#   'Stromae',
#   'Niños Mutantes',
#   'Hola A Todo El Mundo',
#   'The Right Ons',
#   'Sidonie',
#   'JAY Z',
#   'The Bloody Beetroots',
#   'Kanye West',
#   'Peter Doherty',
#   'Los Piratas',
#   'M.I.A.',
#   'Jeanette',
#   'Coldplay',
#   'Amor Fou',
#   'Corizonas',
#   'Loquillo',
#   'The Vaccines',
#   'M83',
#   'Miles Kane',
#   'El Guincho',
#   'La Bien Querida',
#   'Martha Wainwright',
#   'Josh Rouse',
#   'Manel',
#   'Deluxe',
#   'Devendra Banhart',
#   'The Strokes',
#   'Kakkmaddafakka',
#   'Antílopez',
#   'James Blake',
#   'Amaral',
#   'Lana Del Rey',
#   'Anni B Sweet',
#   'Delafe y las flores azules',
#   'Arizona Baby',
#   'Beirut',
#   'The Pinker Tones',
#   'Den svenska björnstammen',
#   'U2',
#   'Two Door Cinema Club',
#   'The Black Keys',
#   'Kasabian',
#   'Red Hot Chili Peppers',
#   'Fira Fem',
#   "Jane's Addiction",
#   'Reptile Youth',
#   'The Last Shadow Puppets',
#   'Gorillaz',
#   'Javiera Mena',
#   'Jack White',
#   'The New Raemon',
#   'Macklemore & Ryan Lewis',
#   'The xx',
#   'Noah And The Whale',
#   'Le Punk',
#   "Noel Gallagher's High Flying Birds",
#   'Beady Eye',
#   'David Bowie',
#   'Bob Dylan',
#   'Spoon',
#   'Thirty Seconds To Mars',
#   'The Hives',
#   'Xoel López',
#   'Vetusta Morla',
#   'El Columpio Asesino',
#   'Crystal Castles',
#   'Los Planetas',
#   'Bruno Mars',
#   'Facto y los amigos del norte',
#   'The Family Rain',
#   'Otis Redding',
#   'Phoenix',
#   'Fiorello',
#   'Los Punsetes',
#   'Jake Bugg',
#   'James Brown',
#   'Egon Soda',
#   'Napoleon Solo',
#   'The Clash',
#   'Inna',
#   'The Dandy Warhols',
#   'Duffy',
#   'The Libertines',
#   'I Break Horses',
#   'Sala & The Strange Sounds feat. Mayte from Baccara',
#   'You Dont know Me',
#   'Placebo',
#   'The Offspring',
#   'Peter Bjorn And John',
#   'MGMT',
#   'León Benavente',
#   'R.E.M.',
#   'Kaiser Chiefs',
#   'Bring Me The Horizon',
#   'George Baker Selection',
#   'Interpol',
#   'Foo Fighters',
#   'Maia Vidal|Marc Ribot',
#   'Yann Tiersen',
#   'Kiko Veneno',
#   'Oh, Libia!',
#   'Fabrizio De André',
#   'Mishima',
#   'Ásgeir',
#   'Good Charlotte',
#   'Miss Caffeina',
#   'Caesars',
#   'Zaz',
#   'Black Strobe',
#   'Black Sabbath',
#   'The Proclaimers',
#   'Belle & Sebastian',
#   'Palmbomen',
#   'Fuzzy White Casters',
#   'Ellos',
#   'Mélanie Pain',
#   'Django Django',
#   'The Kills',
#   'Babyshambles',
#   'Bunbury',
#   'Maia Vidal',
#   'Sala',
#   'Polock',
#   'Owl City',
#   'The Zombie Kids',
#   'Moby',
#   'Icona Pop',
#   'Air',
#   'Katy Perry',
#   'Copiloto',
#   'Jamie Cullum',
#   'OK Go',
#   'Luis Bacalov',
#   'Joaquin Sabina',
#   'Chinese Christmas Cards',
#   'bigott',
#   'Pastora',
#   'Crystal Castles VS Health',
#   'Justice',
#   'Spector',
#   'Vampire Weekend',
#   'Francis White',
#   'Albertucho',
#   'Crystal Fighters',
#   'The Von Bondies',
#   'alt-J',
#   'Patrick Hernandez',
#   'The Academy Orchestra',
#   'Los Bravos',
#   'Bloc Party',
#   'Skrillex',
#   'La Habitación Roja',
#   'Wilco',
#   'The Rolling Stones',
#   'Leiva',
#   'Neon Trees',
#   'Cajun Dance Party',
#   'College & Electric Youth',
#   'Fergie'],
#  '2011': ['Radiohead',
#   'James Blake',
#   'The Strokes',
#   'Smith Westerns',
#   'Wiley',
#   'The Pains Of Being Pure At Heart',
#   'The National',
#   'P Money',
#   'Sepalcure',
#   'M83',
#   'Ghostpoet',
#   'SBTRKT',
#   'Glasvegas',
#   'Tim Hecker',
#   'Mogwai',
#   'Pusha T',
#   'Cant',
#   'Southern Shores',
#   'Goldheart Assembly',
#   'Africa HiTech',
#   'The Streets',
#   'Cults',
#   'EMA',
#   'Warpaint',
#   "Drake feat. Lil' Wayne",
#   'Thao & Mirah',
#   'Dirty Beaches',
#   "P Money ft. OG'z",
#   'Toddla T',
#   'Washed Out',
#   'Marco Del Horno',
#   'The Shutes',
#   'Panda Bear',
#   'Metronomy',
#   'Mj Cole',
#   'Drake',
#   'Gold Panda',
#   'Bon Iver',
#   nan,
#   'The War On Drugs',
#   'Gil Scott-Heron & Jamie xx',
#   'Drake feat. Rick Ross',
#   'Lil Wayne',
#   'About Group',
#   'P Money ft. Germs & Blacks',
#   'Joker',
#   'Pusha T feat. French Montana',
#   'Wise Blood',
#   'Local Natives',
#   'Real Estate',
#   'The Horrors',
#   'Clock Opera',
#   'Alexander Wolfe',
#   'Snoop Dogg',
#   'P Money ft. Wiley & Frisco',
#   'Pusha T feat. Juicy J, Meek Mill, and French Montana',
#   'Kode9',
#   'Beaty Heart',
#   'Strange Talk',
#   'Girls Names',
#   'Youthman',
#   'P Money ft. Little Dee & Blacks',
#   'Shout Out Louds',
#   'Jamie Woon',
#   "P Money ft. OG'z, Drifter & Lady Leeshur",
#   'Darkstar',
#   'Zola Jesus',
#   'P Money ft. Little Dee & Craig',
#   'P Money ft. Craig & Dean Whodini',
#   'Pinback',
#   'Harlem',
#   'Drake feat. Nicki Minaj',
#   'Drake feat. Stevie Wonder',
#   'Rogue Wave',
#   'Phoenix',
#   'Warm Brains',
#   'P Money ft. Kozzie',
#   'P Money ft. Mischief',
#   'Guster',
#   'Death Cab for Cutie',
#   'Broken Bells',
#   'Elbow',
#   'Ok Go',
#   'Nicolas Jaar',
#   'Iron & Wine',
#   'Zomby',
#   'Nada Surf',
#   'P Money ft. Little Dee',
#   'Glasser',
#   'Drake feat. Rihanna',
#   'Detroit Social Club',
#   "Drake feat. Lil' Wayne & Andre 3000",
#   'Zomby/Reark',
#   'How To Dress Well',
#   'The Roots',
#   'Ruff Endz',
#   'Crocodiles'],
#  '2012': ['DJ Rashad',
#   'Big Deal',
#   'JAY Z',
#   'Chairlift',
#   'Drake',
#   'Foster The People',
#   'Zomby',
#   'Bwana',
#   'Cloud Nothings',
#   'Japandroids',
#   'Austra',
#   'King Krule',
#   'Youth Lagoon',
#   'Sepalcure',
#   'Lil Wayne',
#   'Real Estate',
#   'One Direction',
#   'The Roots',
#   'Gotye',
#   'Zulu Winter',
#   'Sufjan Stevens',
#   'Thomas Stenström',
#   'Kobojsarna',
#   'Avicii',
#   'Linnea Henriksson',
#   'Of Monsters and Men',
#   'Far East Movement',
#   'John De Sohn',
#   'John ME',
#   'Simple Plan',
#   'Florence + The Machine',
#   'Newkid',
#   'The Kooks',
#   'Emily Browning',
#   'Calvin Harris',
#   'Justin Bieber',
#   'Katy Perry',
#   'Fun.',
#   'Taio Cruz',
#   'Sixpence None The Richer',
#   'Nicki Minaj',
#   'Lana Del Rey',
#   '3OH!3',
#   'Arty',
#   'The All-American Rejects',
#   'Marina and The Diamonds',
#   'Markus Krunegård',
#   'Jai Paul',
#   'The xx',
#   'SBTRKT',
#   nan,
#   'Maroon 5',
#   'Otto Knows',
#   'Nadia Ali',
#   'Priyanka Chopra',
#   'Norlie & KKV',
#   'Chris Brown',
#   'Ludovico Einaudi',
#   'Alex Ferrari',
#   'Georgina',
#   'Two Rivers',
#   'Efecto Pasillo',
#   'Diego Torres',
#   'P!nk',
#   'Luis Fonsi',
#   'Juan Magan',
#   'Deepside Deejays',
#   'Sak Noel',
#   'Carly Rae Jepsen',
#   'Jose De Rico',
#   'Adele',
#   'No Doubt',
#   'LMFAO',
#   'dr. Bellido',
#   'Sean Paul',
#   'Carlos Jean',
#   'Rasel',
#   'HOFFMAESTRO',
#   'The Band Perry',
#   'Train',
#   'Ke$ha',
#   'Gusttavo Lima',
#   'Alicia Keys',
#   'Madonna',
#   'Owl City',
#   'Serebro',
#   'The Script',
#   'Shakira',
#   'Jennifer Lopez',
#   'Gym Class Heroes',
#   'Ian Carey & Rosette',
#   'Neon Trees',
#   'Michel Teló',
#   'Danny Romero',
#   'PSY',
#   'Alex Ayora',
#   'Swedish House Mafia',
#   'Auryn',
#   'Sons Of Midnight',
#   'Rihanna',
#   'WTF!',
#   'Javi Mula',
#   'Donkeyboy',
#   'MIKA',
#   'Robbie Williams',
#   'Nouvelle Vague',
#   'Bruno Mars',
#   'Cover Drive',
#   'L.A.',
#   'Kelly Clarkson',
#   'Tacabro',
#   'Sie7e',
#   'will.i.am',
#   'EDX & Nadia Ali',
#   'Kylie Minogue',
#   'David Guetta',
#   'Plastilina Mosh',
#   'Taylor Swift',
#   'Crocodiles',
#   'Major Lazer',
#   'Macaco',
#   'Lady Gaga',
#   'Selena Gomez & The Scene',
#   'How To Dress Well',
#   'DJ Antoine',
#   'Ellie Goulding',
#   'Ne-Yo',
#   'Crossfire',
#   'Pol 3.14',
#   'Flo Rida',
#   'Miguel',
#   'Bat For Lashes',
#   'Kendrick Lamar',
#   'John Talabot',
#   'Fuego',
#   'Todd Terje',
#   'Jessie Ware',
#   'Grimes',
#   'Frank Ocean',
#   'Rita Ora',
#   'Mandinga',
#   'Alesso',
#   'Laleh',
#   'Snoop Dogg',
#   'Cali Y El Dandee',
#   'Elena Gheorghe',
#   'Ansiktet',
#   'Christina Aguilera',
#   'Cascada',
#   'The Naked And Famous',
#   'Molly Sandén',
#   'Tyler Ward feat. Jess Moskaluke',
#   'Havana Brown',
#   'Boyce Avenue',
#   'Kanye West',
#   'Amanda Fondell',
#   'Cher Lloyd',
#   'Jessie J',
#   'The Majority Says',
#   'Selena Gomez',
#   'Khaled',
#   'Big Sean',
#   'Panetoz',
#   'Gavin DeGraw',
#   'Matthew West',
#   'Icona Pop',
#   'The Wanted',
#   'Sugababes',
#   'Annie',
#   'Agnes',
#   'The Verve',
#   'Michelle Featherstone',
#   'Rebecca & Fiona',
#   'Ulrik Munther',
#   'Glee Cast',
#   'Usher',
#   'John Mayer',
#   'Imagine Dragons',
#   'Mat Kearney',
#   'B.o.B',
#   'Dada Life',
#   'Kent',
#   'Sebastian Ingrosso',
#   'Lazee feat. Apollo Drive',
#   'Mark Ronson',
#   'McFly',
#   'Alina Devecerski',
#   'Noisettes',
#   'R.E.M.',
#   'Neon Hitch',
#   'Olly Murs',
#   'Gwen Stefani',
#   'The Lumineers',
#   'Belinda Carlisle',
#   'Anarbor',
#   'Jose Gonzales',
#   'Jimmy Eat World',
#   'Demi Lovato',
#   'Enrique Iglesias',
#   'Anton Kristiansson',
#   'Medina',
#   'First Aid Kit',
#   'Darin',
#   'Nause',
#   'Ed Sheeran'],
#  '2012 So Far': ['I:Cube',
#   'The 2 Bears',
#   'Scuba',
#   'This Many Boyfriends',
#   'Pulled Apart By Horses',
#   'The Chap',
#   'John Talabot',
#   'Errors',
#   'Todd Terje'],
#  '2012 TOP SONGS': ['Matthew Dear',
#   'Divine Fits',
#   'Godspeed You! Black Emperor',
#   'Chromatics',
#   'Yazoo',
#   'Grimes',
#   'Twin Shadow',
#   'Cults',
#   'Beach House',
#   'Little Dragon',
#   'Frank Ocean',
#   'PSY',
#   'Fiona Apple',
#   'Jens Lekman',
#   'Hot Chip',
#   'The Strokes',
#   'Blur',
#   'Japandroids',
#   'Fun.',
#   'The xx',
#   'Holy Ghost!',
#   'WU LYF'],
#  '2013': ['Josephine',
#   'Paramore',
#   'Ellie Goulding',
#   'Stone Gods',
#   'Todd Rundgren',
#   'Zulu Winter',
#   'Robin Thicke',
#   'Gary Clark Jr.',
#   'The Very Best',
#   'Black Robot',
#   "Paige O'Hara",
#   'Eliza Doolittle',
#   'Endeverafter',
#   'Pat Benatar',
#   'Stevie Wonder',
#   'David Bowie',
#   'Metallica',
#   'London Grammar',
#   'Whitesnake',
#   'Rick James',
#   'Foreigner',
#   'M.I.A.',
#   'Daughter',
#   'Holy Ghost!',
#   'The Rolling Stones',
#   'Arcade Fire',
#   'Yeasayer',
#   'A$AP Rocky',
#   'Bon Iver',
#   'SBTRKT',
#   'Japandroids',
#   'Alpine',
#   'Balthazar',
#   'Gnarls Barkley',
#   'Lusine',
#   'Rhye',
#   'The Temper Trap',
#   'Justin Timberlake',
#   'Neil Halstead',
#   'Lenny Kravitz',
#   'Two Gallants',
#   'Jon Hopkins',
#   'Kings Of Leon',
#   'Dido',
#   'Bill Withers',
#   'Classixx',
#   'Yuna',
#   'MGMT',
#   'John Wizards',
#   'The National',
#   'Cults',
#   'Otis Redding',
#   'Vampire Weekend',
#   'Daft Punk',
#   'Howard Shore & Metric',
#   'CHVRCHES',
#   'Kanye West',
#   'Earl Sweatshirt',
#   'µ-Ziq',
#   'Disclosure',
#   'Earl Sweatshirt feat. Mac Miller',
#   'Fleetwood Mac',
#   'Haim',
#   'Dismemberment Plan',
#   'Paul McCartney',
#   'Forest Swords',
#   'Franz Ferdinand',
#   'David Lynch',
#   'Joe Cocker',
#   'Bonobo',
#   'Phoenix',
#   'Maluca',
#   'Nine Inch Nails',
#   'Sum 41',
#   'Metric',
#   'Doldrums',
#   'Los Angeles Negros',
#   'Hot Chip',
#   'Simply Red',
#   'Lana Del Rey',
#   'Kate Nash',
#   'Steven Lipson',
#   'Bad Books',
#   'Arctic Monkeys',
#   'Jill Scott',
#   'Kimbra',
#   'Red Astaire',
#   'The Magnetic North',
#   'Hindi Zahra',
#   'Pink Martini',
#   'Röyksopp',
#   'Hauschka',
#   'Nick Drake',
#   'Grasscut',
#   'Blind Melon',
#   'Spiritualized',
#   'Beth Orton',
#   'Junip',
#   'Radiohead',
#   'Rachel Zeffira',
#   'The xx',
#   'Kylie Minogue',
#   'DePedro',
#   'Stereophonics',
#   'Talk Talk',
#   'Andy Burrows',
#   'Anni B Sweet',
#   'Amy Winehouse',
#   'Cave Painting',
#   'Gossip',
#   'Wayne Shorter',
#   'Tracey Thorn',
#   'Everything Everything',
#   'Agnes Obel',
#   'Juliana R',
#   'Andreya Triana',
#   'Nitin Sawhney',
#   'Zee Avi',
#   'Wild Beasts',
#   'alt-J',
#   'Kendrick Lamar',
#   'Ini Kamoze',
#   'Vicci Martinez',
#   'Quarteto Em Cy',
#   'Bruno Mars',
#   'Matt Corby',
#   'Tedeschi Trucks Band',
#   'Poison',
#   'James Arthur',
#   'P!nk',
#   'Robbie Williams',
#   'Ed Sheeran',
#   'Majical Cloudz',
#   'Fun.',
#   'Florence + The Machine',
#   'Passenger',
#   'Mumford & Sons',
#   'The Lumineers',
#   'MIKA',
#   'Billy Joel',
#   'Love of Lesbian',
#   'Donovan',
#   'Jack White',
#   'JAY Z',
#   'The Rapture',
#   'Usher',
#   'Annie',
#   'Macklemore & Ryan Lewis',
#   'La Roux',
#   'Avicii',
#   'Parliament',
#   'Eminem',
#   'Emeli Sandé',
#   'Olly Murs',
#   'Ylvis',
#   'Calvin Harris',
#   'GABRIELLE APLIN',
#   'The Black Keys',
#   'Boards of Canada',
#   'James Blake',
#   'will.i.am',
#   'Alicia Keys',
#   'Icona Pop',
#   'Sia',
#   'Anna Kendrick',
#   'Swedish House Mafia',
#   'Mike Posner',
#   'Owl City',
#   'R. Kelly',
#   'Betty Who',
#   'Bastille',
#   'Goldfrapp',
#   'Asaf Avidan',
#   'Violent Femmes',
#   'Justin Bieber',
#   'Geoff & Maria Muldaur',
#   'Skrillex',
#   'John Legend',
#   'Liquid Liquid',
#   'London Symphony Orchestra',
#   'Leftfield',
#   'Enya',
#   'Freddie Notes & The Rudies',
#   'The Mountain Goats'],
#  '2013 TOP SONGS': ['LCD Soundsystem',
#   'The National',
#   'Stevie Wonder',
#   'Majical Cloudz',
#   'Shane Carruth',
#   'Drake',
#   'Disclosure',
#   'Steven Lipson',
#   'Justin Timberlake',
#   'Haim',
#   'Amon Tobin',
#   'Holy Ghost!',
#   'A$AP Rocky',
#   'M.I.A.',
#   'Franz Ferdinand',
#   'Gil Scott-Heron & Jamie xx',
#   'James Blake',
#   'Nine Inch Nails',
#   'Lana Del Rey',
#   'Metric',
#   'Phoenix',
#   'David Bowie',
#   'Los Porcos',
#   'Vampire Weekend',
#   'The Mountain Goats',
#   'Donovan',
#   'CHVRCHES'],
#  '2013 run mix': ['Azealia Banks',
#   'Bruno Mars',
#   'Hi Fashion',
#   'Neon Trees',
#   'Ellie Goulding',
#   'Avicii',
#   'Lady Gaga',
#   'Deborah Cox',
#   'Macklemore & Ryan Lewis',
#   'Stone Sour',
#   'Emeli Sandé',
#   'Icona Pop',
#   'Ke$ha',
#   'Calvin Harris',
#   'Vampire Weekend'],
#  '2014': ['Daft Punk',
#   'Lana Del Rey',
#   'Alicia Keys',
#   'Indian Summer',
#   'Izal',
#   'Polock',
#   'The Black Keys',
#   'Delafe y las flores azules',
#   'Jack White',
#   'Klaxons',
#   'Royal Blood',
#   'Blue Swede',
#   'Justin Timberlake',
#   'Mélanie Pain',
#   'Kanye West',
#   'Hans Zimmer',
#   'The Smiths',
#   'Phoenix',
#   'The Royal Concept',
#   'Jhene Aiko',
#   'Miss Caffeina',
#   'Antílopez',
#   'Mark Ronson',
#   'RENZO RUBINO',
#   'Bon Iver',
#   'Sidonie',
#   'bigott',
#   'León Benavente',
#   'Devendra Banhart',
#   'The Broken Circle Breakdown Bluegrass Band',
#   'Jake Bugg',
#   'Capital Cities',
#   'M.I.A.',
#   'Vampire Weekend',
#   'Nacho Vegas',
#   'Of Monsters and Men',
#   'Bruno Mars',
#   'Manos De Topo',
#   'Carl Douglas',
#   'Angel Stanich',
#   'The Kooks',
#   'Ásgeir',
#   'Keira Knightley',
#   'Jamie Cullum',
#   'Mucho',
#   'Manu Chao',
#   'Sondre Lerche',
#   'Carlos Sadness',
#   'Kaskade',
#   'El Columpio Asesino',
#   'JAY Z',
#   'Kase.O Jazz Magnetism',
#   'Patrick Hernandez',
#   'The Cure',
#   'KONGOS',
#   'Is Tropical',
#   'Mando Diao',
#   'Lykke Li',
#   'The Lonely Island',
#   'Eminem',
#   'Sebalter',
#   'John Legend',
#   'James Blunt',
#   'Peter Droge & The Sinners',
#   'Afrojack',
#   'Martin Garrix',
#   'Yellow Claw',
#   'Tiësto',
#   'Imagine Dragons',
#   'Beyoncé',
#   'Bill Harvey & His Orchestra',
#   'U2',
#   'Lorde',
#   'Mike & The Mechanics',
#   'Vance Joy',
#   'Avicii',
#   'Clean Bandit',
#   'Noisettes',
#   'Bastille',
#   'Coldplay',
#   nan,
#   'DJ Snake',
#   'American Authors',
#   'Shakira',
#   'Fleetwood Mac',
#   'Mr. Probz',
#   'CHVRCHES',
#   'Colbie Caillat',
#   'Calvin Harris',
#   'Romeo Santos',
#   'Ariana Grande',
#   'Enrique Iglesias',
#   'FKJ',
#   'George Ezra',
#   'El Arrebato',
#   'The War On Drugs',
#   'Belize',
#   'dr. Bellido',
#   'Maroon 5',
#   'Pablo Alboran',
#   'David Bisbal',
#   'Passenger',
#   'Duke Dumont',
#   'Pitbull',
#   'Pharrell Williams',
#   'Haim',
#   'Iggy Azalea',
#   'Leiva',
#   'Pablo López',
#   'Norah Jones',
#   'Alicia Jimenez',
#   'Juan Magan',
#   'Magic!',
#   'David Guetta',
#   'Grises'],
#  '2014 Favorite Tracks': ['The War On Drugs',
#   'Josef Salvat',
#   'Jessie Ware',
#   'MADE IN HEIGHTS',
#   'Faada Freddy',
#   'How To Dress Well',
#   'Tourist',
#   'Death From Above 1979',
#   'Ryan Adams',
#   'Duck Sauce',
#   'Wild Beasts',
#   'Preson Phillips',
#   'Noah Gundersen',
#   'Bombay Bicycle Club',
#   'Gorgon City',
#   'Tangerine',
#   'Naughty Boy',
#   'NONONO',
#   'Tinashe',
#   'Caribou',
#   'SOHN',
#   'ODESZA',
#   'Banks',
#   'John Mark McMillan',
#   'Conor Oberst',
#   'Sinceyou',
#   'Copeland',
#   'Joe Day',
#   'Moonface',
#   'Owl John',
#   'Luke James',
#   'Nico & Vinz',
#   'Jungle',
#   'Chromeo',
#   'Real Estate',
#   'Tycho'],
#  '2014 Gigs': ['Hip Route',
#   'Emily Barker & The Red Clay Halo',
#   'The Deep Dark Woods',
#   'Sons Of Bill',
#   'Shearwater',
#   'White Denim',
#   'Keston Cobblers Club',
#   'Trembling Bells',
#   'Russ Poole'],
#  '2014 Rewind': ['Clark Terry',
#   'The Broken Circle Breakdown Bluegrass Band',
#   'The Isley Brothers',
#   'Boney M.',
#   'Talking Heads',
#   'Ella Fitzgerald',
#   'Chaka Khan',
#   'Body Language',
#   'Quantic',
#   'Roy Ayers Ubiquity',
#   'How To Dress Well',
#   'The Dinning Sisters',
#   'Crystal Castles',
#   'Valerie June',
#   'Blood Orange',
#   'Laurel Halo',
#   'Classixx',
#   'Aaliyah',
#   'Ciara',
#   'Lewis Taylor',
#   'Inc.',
#   'Abdullah Ibrahim',
#   'E.T. Mensah',
#   'Rafael Encarnación',
#   'The RH Factor',
#   'Jai Paul',
#   'Mal Waldron'],
#  '2014 Y/E': ['Aphex Twin',
#   "D'Angelo",
#   'St. Vincent',
#   'Flying Lotus',
#   'Mogwai',
#   'Spoon',
#   'TV On The Radio',
#   'The Rapture',
#   'Beck',
#   'Lorde',
#   'Sky Ferreira',
#   'Röyksopp & Robyn',
#   'SBTRKT',
#   'Anthony Gonzalez',
#   'Fuck Buttons',
#   'Rustie',
#   'Future Islands',
#   'Ben Frost',
#   'The Drums',
#   'Liars',
#   'Youth Lagoon',
#   'Mica Levi',
#   'Shamir',
#   'Todd Terje',
#   'YACHT',
#   'M83',
#   'Phantogram',
#   'Muse',
#   'Grimes',
#   'Liturgy'],
#  '2014 beginning ': ['The Vaccines',
#   'Mat Kearney',
#   'Frank Turner',
#   'Passenger',
#   'The Twang',
#   'Joshua Radin',
#   'Oasis',
#   'The Killers',
#   'Arctic Monkeys',
#   'McFly',
#   'Jimmy Eat World',
#   'Stooshe',
#   'The Kooks',
#   'GABRIELLE APLIN',
#   'Tom Odell',
#   'Oasis For Piano',
#   'Half Moon Run',
#   'A Great Big World',
#   'Macklemore & Ryan Lewis',
#   'Kimya Dawson',
#   'CHVRCHES',
#   'Newton Faulkner',
#   'Riders In The Sky',
#   'Belle & Sebastian',
#   'Bowling For Soup',
#   'Lilygreen & Maguire',
#   'Vance Joy',
#   'The 1975',
#   'Flogging Molly',
#   'Babyshambles',
#   'Snow Patrol',
#   'The Enemy',
#   'Lifehouse',
#   'Kaiser Chiefs',
#   'Ed Sheeran',
#   'The Libertines',
#   'Pete Yorn',
#   'The Rifles',
#   'The View',
#   'Coldplay',
#   'Butterfly Boucher',
#   'Bastille',
#   'Beans On Toast',
#   'James Blunt',
#   'Rascal Flatts',
#   'Eliza Doolittle',
#   'The Beach Boys',
#   'Barenaked Ladies',
#   'Daniel Powter',
#   'Michael Cera & Ellen Page',
#   'Counting Crows',
#   '[500] Days Of Summer - Music From The Motion Picture',
#   'Noah And The Whale',
#   'The Offspring',
#   'The Fratellis',
#   'Mumm-ra',
#   'Squeeze',
#   'Katy Perry',
#   'Jason Derulo',
#   'Jack Penate',
#   'Band of Horses',
#   'Biffy Clyro',
#   'The Pigeon Detectives',
#   'Taylor Swift',
#   'The Courteeners',
#   'Placebo',
#   'Uncle Kracker',
#   'Elise Lieberth',
#   'The Wanted',
#   'Sum 41',
#   'Jack Johnson',
#   'Edwin McCain',
#   'Sugarland',
#   'Sarah Blasko',
#   'The Ordinary Boys',
#   'Various Artists',
#   'The Stone Roses',
#   'Avicii',
#   'Meaghan Smith',
#   'Little Jackie',
#   'Third Eye Blind',
#   'Steve Earle',
#   'Lily Allen'],
#  '2014 crack - check outs': ['Rustie', 'Cloud Nothings', 'Tirzah', 'Vessel'],
#  '2015': ['If Moving Your Mine', 'Maroon 5', 'Ed Sheeran'],
#  '2080': ['2080'],
#  '20Syl playlist': ['Gang Starr',
#   "D'Angelo",
#   'Common',
#   'Stevie Wonder',
#   'Shiggy Sha',
#   'Scarface',
#   'Krumbsnatcha',
#   'K-Ci'],
#  '20th': ['Eliza Doolittle',
#   'Adele',
#   'Bastille',
#   'NEEDTOBREATHE',
#   'Nicole Scherzinger',
#   'Nightwish',
#   'Lady Gaga',
#   'Ke$ha',
#   'Hugh Grant',
#   'P!nk',
#   'Taylor Swift',
#   'All Time Low',
#   'Electric Light Orchestra',
#   'The Wombats',
#   'Katrina & The Waves',
#   'Hollywood Undead',
#   'Avicii',
#   'Evanescence',
#   'Train',
#   'Calvin Harris',
#   'Mayday Parade',
#   'MIKA',
#   'Black Eyed Peas',
#   'The Goo Goo Dolls',
#   'The Fray',
#   'Eddie Murphy'],
#  '21st Century Disco': ['SBTRKT',
#   'Beat Connection',
#   'Jonas Rathsman',
#   'Anoraak',
#   'Perseus',
#   'Tobtok',
#   'The Embassy',
#   'Gigamesh',
#   'Processory',
#   'Capital Cities',
#   'Vanguard',
#   'Atmosfear',
#   'Sare Havlicek',
#   'Fancy',
#   'Nile Delta',
#   'Uniforms For The Dedicated',
#   'French Horn Rebellion',
#   'Punks Jump Up',
#   'Jazzy Eyewear',
#   'Discotexas',
#   'Spiller',
#   'Novika',
#   'RAC feat. Penguin Prison',
#   'Lazydisco',
#   'Chordashian',
#   'Todd Terje',
#   'Surkin',
#   'Small Pyramids',
#   'Edwin van Cleef',
#   'The Magician',
#   'Fred Falke',
#   'Bestrack',
#   'Viceroy',
#   'EDX',
#   'Daft Punk',
#   'Moonlight Matters',
#   'David Rubato',
#   'Volta Cab',
#   'Mykill'],
#  '24/7 Rangers': ['The Black Keys', 'M83', 'Sigur Rós'],
#  '25 Artists in 2015': ['Mark Ronson',
#   'Tyler Carter',
#   'Yeo',
#   'Broods',
#   'Polyenso',
#   'Raury',
#   'The Districts',
#   'Catfish and the Bottlemen',
#   'MisterWives',
#   'BØRNS',
#   'Little May',
#   'Joey Bada$$',
#   'Years & Years',
#   'James Bay',
#   'Hail Mary Mallon',
#   'Glass Animals',
#   'Boots',
#   'Jon Bellion',
#   'Alex Wiley',
#   'SBTRKT',
#   'Marian Hill',
#   'Ryn Weaver',
#   'All Get Out',
#   'M.T.G'],
#  '2CELLOS': ['2Cellos'],
#  '2Cellos': ['2Cellos'],
#  '2Pac': ['2Pac', 'MGMT'],
#  '2Pac – 2Pac Greatest Hits': ['2Pac'],
#  '2step feel good': ['Craig David',
#   'Disclosure',
#   'Architechs',
#   'Mj Cole',
#   'Moon Boots',
#   'Glamma Kid',
#   'JAY Z',
#   'Artful Dodger And Romina Johnson',
#   'Artful Dodger Featuring Michelle Escoffery',
#   'David Morales Presents The Face'],
#  '3.29 Store Meeting': ['Meghan Trainor',
#   'N Sync',
#   'Matt and Kim',
#   'CeCe Peniston',
#   'Will Smith',
# ...
#   'Vern Gosdin',
#   'Sammy Kershaw',
#   'Ronnie Milsap',
#   'Blake Shelton',
#   'Jerrod Niemann',
#   'Diamond Rio',
#   'Eric Church',
#   'Jamey Johnson',
#   'Darryl Worley',
#   'Hank Williams, Jr.',
#   'John Anderson',
#   'Billy Dean',
#   'Johnny Lee',
#   'Jake Owen',
#   'Kenny Chesney',
#   'Johnny Horton',
#   'Josh Turner',
#   'Trace Adkins',
#   'Kip Moore',
#   'Rhett Akins',
#   'Collin Raye',
#   'Rodney Atkins',
#   'George Strait',
#   'Waylon Jennings',
#   'Eli Young Band',
#   'Travis Tritt',
#   'Billy Ray Cyrus',
#   'Little Jimmy Dickens',
#   'Randy Travis',
#   'Shenandoah',
#   'Clint Black',
#   'Tracy Lawrence',
#   'David Lee Murphy',
#   'Kacey Musgraves',
#   'David Allan Coe',
#   'Vince Gill',
#   'Confederate Railroad',
#   'Florida Georgia Line',
#   'Jason Michael Carroll',
#   'Aaron Tippin',
#   'Doug Stone',
#   'Dixie Chicks',
#   'Old Crow Medicine Show',
#   'Neal McCoy',
#   'Tracy Byrd',
#   'Josh Thompson',
#   'Daryle Singletary',
#   'George Jones',
#   'Roger Miller',
#   'Ricky Skaggs',
#   'Lee Brice',
#   'Dwight Yoakam',
#   'Aaron Lewis',
#   'The Bellamy Brothers',
#   'Blackberry Smoke',
#   'The Kentucky Headhunters',
#   'Mark Chesnutt',
#   'Marty Stuart',
#   'Eddie Rabbitt',
#   'Steve Azar',
#   'Mark Wills',
#   'The Statler Brothers',
#   'Jimmy Dean',
#   'Colt Ford',
#   'Michael Peterson',
#   'Nitty Gritty Dirt Band',
#   'Charlie Worsham',
#   'Steve Earle And The Dukes',
#   'Chris LeDoux',
#   'Easton Corbin',
#   'Buck Owens',
#   'Dan Seals',
#   'Brantley Gilbert'],
#  'Country 8-16': ['Jason Aldean',
#   'Lady Antebellum',
#   'Luke Bryan',
#   'Brooks & Dunn',
#   'Keith Urban',
#   'Blake Shelton',
#   'Brantley Gilbert',
#   'Miranda Lambert',
#   'Shania Twain',
#   'Dierks Bentley',
#   'Hunter Hayes',
#   'Dwight Yoakam',
#   'Toby Keith'],
#  'Country Ballads': ['Tim McGraw',
#   'Sara Evans',
#   'Gary Allan',
#   'Mickey Guyton',
#   'Trisha Yearwood',
#   'Miley Cyrus',
#   'Jason Aldean',
#   'Crystal Gayle'],
#  'Country Burkburnett': ['Shania Twain',
#   'Keith Urban',
#   'Brooks & Dunn',
#   'Gretchen Wilson',
#   'Miranda Lambert',
#   'Blake Shelton',
#   'Carrie Underwood',
#   'Little Big Town',
#   'Hank Williams, Jr.',
#   'Lady Antebellum'],
#  'Country Warm-Up': ['David Nail',
#   'Brett Eldredge',
#   'Sam Hunt',
#   'Thomas Rhett',
#   'Jimmy Wayne'],
#  'Country/Country Rock/Pop Country/Southern Rock': ['Snoop Dogg',
#   'Darius Rucker',
#   'Kings Of Leon',
#   'Toby Keith',
#   'Luke Bryan',
#   'Hank Williams',
#   'Hugo',
#   'Jimmie Rodgers',
#   'Josh Turner',
#   'Johnny Cash',
#   'Hank Williams, Jr.',
#   'Willie Nelson',
#   'Taylor Swift',
#   'Lauren Alaina'],
#  'Cours de Danse – Cours de Danse et école de danse - Musique et danse classique': ['Cours de Danse',
#   'Robert Plant'],
#  'Covers nice': ['Placebo',
#   'Jay Smith',
#   'Jesse & Joy',
#   'Nirvana',
#   'Marilyn Manson',
#   'Scissor Sisters',
#   'The Wallflowers',
#   'Chris Cornell',
#   'Cake',
#   'Ellie Goulding',
#   'HIM',
#   'Robbie Williams',
#   'Depeche Mode'],
#  'Covers with a Twist': ["Blackmore's Night",
#   'Tanya Sunshine',
#   'The Forms',
#   'The Blood Brothers',
#   'Manic Street Preachers',
#   'String Tribute Players',
#   'Dj Joxx Feat. A.L',
#   'Vasco & Millboy Feat. The Gladiator',
#   'Bobby Womack',
#   'Wayne Pascall',
#   'The Mooney Suzuki',
#   'Superchunk',
#   'Joe F',
#   'Devendra Banhart',
#   'Cam Fox',
#   'Vanessa-Mae',
#   'Porter Block',
#   'Galaxia',
#   'Thea Austin'],
#  'Covers worth listening to': ['Sepultura',
#   'Michael Franti & Spearhead',
#   'Shiny Toy Guns',
#   'Carpathian Forest'],
#  'Covers, covers, covers!': ['Me First and the Gimme Gimmes',
#   'MxPx',
#   'Social Siberia',
#   'The Beautiful South',
#   'Television',
#   'Jake Shimabukuro',
#   'The Offspring',
#   'The Vandals',
#   'Goldfinger',
#   'Sandro y Los de Fuego',
#   'Frank Turner',
#   'Apocalypstik',
#   'PJ Bond',
#   'The Donnas',
#   'Reel Big Fish',
#   'Green Day',
#   'Acoustic Hits',
#   'The Used/My Chemical Romance',
#   'Attaque 77',
#   'The Muffs',
#   'NOFX',
#   'Sid Vicious',
#   'Friccion',
#   'The Rural Alberta Advantage',
#   'Johnny Cash',
#   'Alien Ant Farm',
#   'Ramones',
#   'El Nido Del Cuco',
#   'VersaEmerge',
#   'Talco'],
#  'Cow Pies': ['Josh Turner',
#   'Hank Williams',
#   'Randy Travis',
#   'Randy Travis with George Jones',
#   'Randy Travis with Tammy Wynette',
#   'Greater Vision'],
#  'Craft Beer Party 2014': ['Sleigh Bells',
#   'Outasight',
#   'Daft Punk',
#   'Kanye West',
#   'JAY Z',
#   'Iggy Azalea',
#   'R. Kelly',
#   'Jason Derulo',
#   'Robin Thicke',
#   'Chiddy Bang',
#   'Pharrell Williams',
#   'Ke$ha',
#   'OutKast',
#   'Estelle',
#   'Paramore',
#   'Tinie Tempah',
#   'M.I.A.',
#   'Ariana Grande',
#   'Kid Cudi',
#   'Imagine Dragons',
#   'Walk the Moon',
#   'Travie McCoy',
#   '2AM Club',
#   'Lupe Fiasco',
#   'Pete Rock & C.L. Smooth'],
#  'Crazy Crazy Nights': ['Europe',
#   'Great White',
#   'Sammy Hagar',
#   'Queensrÿche',
#   'Bulletboys',
#   'Y&T',
#   'Mr. Big',
#   'Whitesnake',
#   'Heart',
#   'Twisted Sister',
#   'White Lion',
#   'Scorpions',
#   'Electric Boys',
#   'Alice Cooper',
#   'Dokken',
#   'Night Ranger',
#   'Tesla',
#   'Ratt',
#   'Cinderella',
#   'D-A-D',
#   'Kingdom Come',
#   'KISS',
#   'Skid Row',
#   'Faith No More',
#   'Poison',
#   'Extreme',
#   'Living Colour',
#   'Helloween',
#   'Giant',
#   'David Lee Roth',
#   'The Cult',
#   'Judas Priest',
#   'Quiet Riot',
#   'Warrant',
#   "Enuff Z'Nuff"],
#  'Crazy For You - Original London Cast – Crazy For You - Original London Cast': ['Crazy For You - Original London Cast'],
#  'CreamTeam': ['SBTRKT',
#   'Rustie',
#   'James Blake',
#   'Dam Mantle',
#   'Girls',
#   'Rudi Zygadlo',
#   'Jessica Says',
#   'Homeboy Sandman',
#   'LV',
#   'Chandeliers',
#   'Puro Instinct',
#   'T.I.',
#   'Frank Ocean',
#   'Rhye',
#   'Onra',
#   'Julien Doré',
#   'Bullion',
#   'Real Estate',
#   'Cuticle',
#   'XXXY',
#   'Zomby',
#   'Astronautalis',
#   'Lost Animal',
#   'Diskjokke',
#   'Mo Kolours',
#   'Balam Acab',
#   'Unicycle Loves You',
#   'tUnE-yArDs',
#   'Destroyer',
#   'Lilacs & Champagne',
#   'Kishi Bashi',
#   'Tomorrows Tulips',
#   'Myrryrs',
#   'Sigur Rós',
#   'ESG',
#   'When Saints Go Machine',
#   'Jonti',
#   'Lindstrøm',
#   'White Denim',
#   'Death In Vegas',
#   'Monica',
#   'Arca',
#   'Bleached',
#   'Puerto Rico Flowers',
#   'Ocelote Rojo',
#   'Nicolas Jaar',
#   'Gulp',
#   'Jai Paul',
#   'Veronica Falls',
#   'Kotki Dwa',
#   'Sepalcure',
#   'Future',
#   'Danny Brown',
#   'Blood Orange',
#   'Stone Darling'],
#  'Creed – Greatest Hits': ['Creed'],
#  'Creedence Clearwater Revival – At The Movies': ['Creedence Clearwater Revival'],
#  'Crime In Stereo – I Was Trying To Describe You To Someone': ['Crime In Stereo'],
#  'Cristal': ['Fink',
#   'Vib Gyor',
#   'Coldplay',
#   'Tannhauser',
#   'Spiritualized',
#   'Lali Puna',
#   'Sting',
#   'The Killers',
#   'The Temper Trap',
#   'Keane',
#   'Micah P. Hinson',
#   'Mattias IA Eklundh',
#   'Hiromi Uehara',
#   'Kasket Club',
#   'Angus & Julia Stone',
#   'Lykke Li',
#   'Bonobo',
#   'Mayer Hawthorne',
#   'Chilly Gonzales',
#   'Holy Fuck',
#   'Miami Horror',
#   'Marco Dos Santos',
#   'Moloko',
#   'Beach House',
#   'Ladyhawke',
#   'Foals',
#   'Theme Park',
#   'Kasabian',
#   'Johann Pachelbel',
#   'Alicia Keys',
#   'The Script',
#   'Stan Getz',
#   'Delorean',
#   'Tristeza',
#   'U2',
#   'Telepopmusik',
#   'Tsidii Le Loka',
#   'Empire Of The Sun',
#   'Peter Bjorn And John',
#   'Seinabo Sey',
#   'James Bay',
#   'Explosions In The Sky',
#   'Jason Raize',
#   'Cold War Kids'],
#  'Crooners': ['Dean Martin', 'Mel Torme', 'Bobby Darin'],
#  'Croque le monde #2': ['Cake'],
#  'Croque le monde #3': ['Joey Pecoraro',
#   'The Doppelgangaz',
#   'mtbrd',
#   'Junoflo',
#   'Blazo',
#   'Handbook',
#   'Les Loups',
#   'Derlee',
#   'Vanilla',
#   'Tez Cadey'],
#  'Croque le monde #4': ['The Handsome Family',
#   'Eden Ahbez',
#   'Slow Club',
#   'Rodrigo Amarante',
#   'Joe Purdy',
#   'Buffalo Springfield',
#   'Neil Young',
#   'Moondog',
#   'Link Wray'],
#  'Croque le monde #5': ['Azymuth',
#   'Carte Blanche',
#   'Cortex',
#   'Change',
#   'TNT Boys',
#   'Sweet Smoke',
#   'Sonia Rosa',
#   'Zapp',
#   'Ben & The Platano Group',
#   'Bob James'],
#  'Crosby, Stills & Nash – CSN 2012': ['Crosby, Stills & Nash'],
#  'Crow – The Crow Original Motion Picture Soundtrack': ['For Love Not Lisa',
#   'Machines Of Loving Grace',
#   'Stone Temple Pilots',
#   'The Jesus And Mary Chain',
#   'Rollins Band',
#   'Medicine',
#   'My Life With The Thrill Kill Kult',
#   'Helmet',
#   'Nine Inch Nails',
#   'Pantera',
#   'Jane Siberry',
#   'Rage Against The Machine',
#   'The Cure',
#   'Violent Femmes'],
#  'Crystal Age – Far Beyond Divine Horizons': ['Crystal Age',
#   'Mithras',
#   'Nocturnus'],
#  'Crystal Castles - (III)': ['Crystal Castles'],
#  'Crystal Castles – (III)': ['Crystal Castles'],
#  'Crystal Castles – Crystal Castles': ['Crystal Castles',
#   'Crystal Castles vs. Health'],
#  'Cuarteto Caney – Cuarteto Caney (1939-1940) Featuring Machito': ['Cuarteto Caney'],
#  'Cubano': ['Buena Fe',
#   'Jessica Rodriguez',
#   'Kalunga',
#   'Joaquin Sabina',
#   'Carlos Varela',
#   'Haydee Milanes',
#   'Pablo Milanés',
#   'Ivett Cepeda',
#   'Frank Fernández',
#   'Pancho Amat Y El Cabildo Del Son'],
#  'Cuddly Toy - Single Version': ['Roachford'],
#  'Cults – Static': ['Cults'],
#  'Culture Club': ['Culture Club'],
#  'Cumple 29': ['Los Rodriguez',
#   'Paul Simon',
#   'Adam Green',
#   'Los Fabulosos Cadillacs',
#   'Eric Clapton',
#   'Elton John',
#   'The Doors',
#   'Bob Marley',
#   'Queen',
#   'Green Day',
#   'Los Redondos',
#   'U2',
#   'Kane',
#   'Andrés Calamaro - Fito & Fitipaldis',
#   'Johnny Cash',
#   'Tequila',
#   'Amy Macdonald',
#   'Dire Straits',
#   'The Beatles',
#   'Los Tres',
#   'Andrés Calamaro',
#   'Serú Girán',
#   'Manu Chao',
#   'Adele',
#   'Me First And The Gimme Gimmes',
#   'Counting Crows',
#   'The Police',
#   'Sumo',
#   'Rolling Stones',
#   'Joaquín Sabina',
#   'Brian Wilson',
#   'Sergio Mendes',
#   'Bon Jovi',
#   'The Who',
#   'Santana',
#   'Enanitos Verdes',
#   'Divididos',
#   'Nirvana',
#   'Paco De Lucia',
#   'Violadores',
#   'MIKA',
#   'Herman Brood',
#   'Gorillaz',
#   'The Killers',
#   'Rubén González',
#   'Charly Garcia',
#   'Oasis',
#   'Ramones',
#   'Red Hot Chili Peppers',
#   'UB40',
#   'Dusty Springfield',
#   'Fabiana Cantilo',
#   'Tonton David',
#   'Al Green',
#   'Heather Nova',
#   'Bersuit Vergarabat',
#   'Fito & Fitipaldis',
#   'The Cure',
#   'Robert Johnson',
#   "Guns 'n' Roses",
#   'NOFX',
#   'Lenny Kravitz',
#   'Bunny Rugs',
#   'Colbie Caillat',
#   'The Cardigans',
#   'Pereza',
#   'The Gaslight Anthem',
#   'John Hiatt',
#   'Bruce Springsteen',
#   'Sex Pistols',
#   'Jimmy Cliff',
#   'Eagles',
#   'Yellowman',
#   'Genesis',
#   'Elvis Presley',
#   'Bob Dylan',
#   'Amy Winehouse',
#   'Neil Young',
#   'Seasick Steve',
#   'Nils Lofgren',
#   'Creedence Clearwater Revival',
#   'AC/DC',
#   'Mark Knopfler',
#   'Led Zeppelin',
#   'Various Artists',
#   'The Kinks',
#   'Foreigner',
#   'Chaka Demus & Pliers',
#   'Phil Collins',
#   'Coldplay',
#   'Frank Zappa',
#   'Bob Seger',
#   'Steven Tyler',
#   'Los Pericos',
#   'Sting',
#   'Los Piojos',
#   'Groove Deluxe remix',
#   'Robbie Williams',
#   'Muchachito Bombo Infierno',
#   'Metallica',
#   'Eminem',
#   'Jack Johnson',
#   'Joe Satriani',
#   'Van Morrison',
#   'Wire',
#   'The Clash',
#   'Soundtrack',
#   'Pierpoljak',
#   'Bacardi',
#   'Stevie Ray Vaughan',
#   'Ziggy Marley & The Melody Makers',
#   'Bad Religion'],
#  'Current': ['Kanye West',
#   'Nancy Ajram',
#   'JAY Z',
#   "K'NAAN",
#   'Michael Jackson',
#   'Kelly Rowland',
#   'P-Square',
#   'Drake',
#   'Roar',
#   'Rihanna',
#   'The Very Best',
#   'Chaka Demus & Pliers',
#   'Diddy',
#   'Beyoncé'],
#  'Current Country': ['Leah Turner',
#   'Reba McEntire',
#   'Sam Hunt',
#   'Chris Young',
#   'Florida Georgia Line',
#   'Dierks Bentley',
#   'Blake Shelton',
#   'Kelsea Ballerini',
#   'Brad Paisley',
#   'Cole Swindell',
#   'Luke Bryan',
#   'Thomas Rhett',
#   'Chris Janson',
#   'Zac Brown Band',
#   'A Thousand Horses',
#   'Brandy Clark',
#   'Little Big Town'],
#  'Current Favorites': ['Nick Jonas',
#   'Tony Bennett',
#   'Ariana Grande',
#   'Marlena Shaw',
#   'Young Pandas',
#   'Sia',
#   'Naughty Boy',
#   'Phantogram',
#   'Echosmith',
#   'Alabama Shakes',
#   'Maroon 5',
#   'Lady Gaga',
#   'Incubus',
#   'Tove Lo',
#   'Har Mar Superstar',
#   'Beyoncé',
#   'Meghan Trainor',
#   'Muse',
#   'Alex Winston',
#   'Hozier',
#   'Nicki Minaj',
#   'Neon Trees',
#   'Disclosure',
#   'Lorde'],
#  'Curtida no Rádio': ['Arch Enemy',
#   'Disturbed',
#   'letlive.',
#   'Circa Survive',
#   'blessthefall',
#   'Chiodos',
#   'Genedefect',
#   'The Color Morale',
#   'Alien Ant Farm',
#   'Lily Allen',
#   'Hands Like Houses',
#   'The Paramedic',
#   'Slipknot',
#   'Duffy',
#   'Fightstar',
#   'Oasis',
#   'Red Hot Chili Peppers',
#   'Bring Me The Horizon',
#   'Marmozets',
#   'SycAmour',
#   'Memphis May Fire',
#   'Wiz Khalifa',
#   'Motionless In White',
#   'Of Mice & Men',
#   'A Day To Remember',
#   'Rage Against The Machine',
#   'Kendrick Lamar',
#   '3 Doors Down',
#   'Korn',
#   "Jamie's Elsewhere",
#   'Papa Roach',
#   'Arctic Monkeys',
#   'Machinatx',
#   'Incubus',
#   'The Red Jumpsuit Apparatus',
#   'Nickelback',
#   'Crown The Empire',
#   'Speakers For The Dead',
#   'Killswitch Engage',
#   'Emarosa',
#   'Hinder',
#   'Storm The Sky',
#   'Audioslave',
#   'Issues',
#   'Pierce The Veil',
#   'Woe, Is Me',
#   'Three Days Grace',
#   'Static-X',
#   'Falling In Reverse',
#   'Heartist',
#   'I See Stars',
#   'The Neighbourhood',
#   'The Color Morale feat. Dave Stephens',
#   'Schoolboy Q',
#   'Stone Sour',
#   'Adestria',
#   'Trivium',
#   'The Used',
#   'Confide',
#   'Asking Alexandria',
#   'Foo Fighters',
#   'Atlas Genius',
#   'The Pierces',
#   'Janis Joplin',
#   'Buffalo Springfield',
#   'The Doors',
#   'Kaiser Chiefs',
#   'Weezer',
#   'Peter Bjorn And John',
#   'Blur',
#   'The Kinks',
#   "Guns N' Roses",
#   'Kings Of Leon',
#   'The Strokes',
#   'Jefferson Airplane',
#   'The Offspring',
#   'Casey Veggies',
#   'Frank Ocean',
#   'Adele',
#   'Muse',
#   'Yelawolf',
#   'Twenty One Pilots',
#   'Breaking Benjamin',
#   'Five Finger Death Punch',
#   'Jonny Craig',
#   'Eagles',
#   'The Black Keys',
#   'R.E.M.',
#   'The Last Shadow Puppets',
#   'Fearless Vampire Killers',
#   'The Police',
#   'Metallica',
#   'Journey',
#   'The Animals',
#   'Franz Ferdinand',
#   'The Rolling Stones',
#   'Cage The Elephant',
#   'Kansas',
#   'Queen',
#   'Soundgarden',
#   'The Verve',
#   'Shocking Blue',
#   'Bon Jovi',
#   'Cream',
#   'The Hives',
#   'In Fear And Faith',
#   'Thirty Seconds To Mars',
#   'Star Off Machine',
#   'From Indian Lakes',
#   'The Seeking',
#   'I The Mighty',
#   'Element Eighty',
#   'From First To Last',
#   'Modest Mouse',
#   'Blessthefall feat. Jake Luhrs',
#   'Steppenwolf',
#   'ZOAX',
#   'Boston',
#   'Lil Wayne',
#   'Puddle Of Mudd',
#   'Now, Now',
#   'Black Label Society',
#   'Lost Autumn',
#   'Our Last Night',
#   'Funeral For A Friend',
#   'Escape the Fate',
#   'Taking Back Sunday',
#   'I Am King',
#   'System Of A Down',
#   'Interpol',
#   'The Charm The Fury',
#   'Underoath',
#   'Moving Mountains',
#   'Upon This Dawning',
#   'Nine Lashes',
#   'Jack White',
#   'In Flames',
#   'Monuments',
#   'Pvris',
#   'Silverstein',
#   'Mudvayne',
#   'Red',
#   'Blessthefall feat. Lights'],
#  'Cut Copy – Cut Copy Presents: Oceans Apart': ['Knightlife',
#   'Michael Ozone',
#   'Len Leise',
#   'Andras & Oscar',
#   "World's End Press",
#   'Sleep D',
#   'Statue',
#   'Coober Pedy University Band',
#   'Ara Koufax',
#   'Speed Painters',
#   'Belltowers',
#   'AO',
#   'Fantastic Man',
#   'Myles Mac',
#   'Nile Delta',
#   'Roland Tings',
#   'Tornado Wallace',
#   'No Zu',
#   'Turkish Prison'],
#  'Cuéntame Los 80': ['Jennifer Rush',
#   'Ray Parker, Jr.',
#   'Baltimora',
#   'Spandau Ballet',
#   'Miguel Bosé',
#   'Joaquin Sabina',
#   'Tequila',
#   'Loquillo Y Los Intocables',
#   'Limahl',
#   'Paraiso',
#   'Antonio Flores',
#   'Cyndi Lauper',
#   'Video',
#   'Duran Duran',
#   'Daryl Hall & John Oates',
#   'Ejecutivos Agresivos',
#   'The Alan Parsons Project',
#   'Los Toreros Muertos',
#   'Zombies',
#   'Los Ronaldos',
#   'Los Chunguitos',
#   'Heroes Del Silencio',
#   'Alaska Y Los Pegamoides',
#   'COZ',
#   'Pecos',
#   'Culture Club',
#   'Alaska Y Dinarama',
#   'Ole Ole',
#   'Nacha Pop',
#   'Ramoncin',
#   'Ricchi E Poveri',
#   'Kenny Loggins',
#   'Ivan',
#   'Bibi Andersen',
#   'Survivor',
#   'Obus',
#   'Daniela Romo',
#   'Katrina & The Waves',
#   'Tina Turner',
#   'Modern Talking',
#   'Glutamato Ye-Ye',
#   'Orquesta Mondragon',
#   'Orchestral Manoeuvres In The Dark',
#   'Loquillo Y Los Trogloditas',
#   'Yuri',
#   'Los Rebeldes',
#   'Pistones',
#   'Yazoo',
#   'Pedro Marin',
#   'El Último De La Fila',
#   'Estrella Morente',
#   'Ryan Paris',
#   'The Human League',
#   'Tino Casal',
#   'Polansky y El Ardor',
#   'Kim Carnes',
#   'Mecano',
#   'Gabinete Caligari',
#   'Lain'],
#  'Cycle – Stripped': ['Cycle'],
#  ...}

# %%
# define undirected graph
G = nx.Graph()
# create all the nodes, each one representing an artist
for playlist, artist_list in playlists.items():
    G.add_nodes_from(artist_list)
    # create the edge list where we fully connect all the nodes to each other
    # edge_list = get_edges(artist_list)
    # G.add_edges_from(edge_list)
